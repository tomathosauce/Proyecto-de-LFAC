# %% [markdown]
# # Text Classification with Transformers (ALBERT)
#
# This script helps you fine-tune a pre-trained model (ALBERT) and encoder model for text classification with a dataset from the HuggingFace.
#
# The use case uses binary classes to produce a model to identify clickbait versus factual content with the use of a synthetic dataset found [here](https://huggingface.co/datasets/ilsilfverskiold/clickbait_titles_synthetic_data). This script follows a tutorial that you can find here.
#
# You may use any encoder model such as BERT, RoBERTa and DeBERTa instead.

# %%
# !pip install -U datasets
# !pip install -U accelerate
# !pip install -U transformers
# !pip install -U huggingface_hub
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.31.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.6.2)

# %%
import pandas as pd

good = pd.read_csv('./good.csv')
bad = pd.read_csv('./bad.csv')

ds = pd.concat([good, bad], axis=0)
ds
# Out:
#                                                 sentence label
# 0      ( ( ( variable ) - [ variable ] - number + var...  good
# 1      [ number number - variable number + variable v...  good
# 2      ( [ variable number * ] - variable ) / ( numbe...  good
# 3      number * [ variable ] + ( number / ( number ) ...  good
# 4          ( ( number ) ) + number + variable - variable  good
# ...                                                  ...   ...
# 19995  variable * [ variable number variable variable...   bad
# 19996  [ variable number variable * * ] / [ ] number ...   bad
# 19997  ( [ number number / variable number - - number...   bad
# 19998  variable * [ variable variable variable + vari...   bad
# 19999  [ variable variable variable variable / / vari...   bad
#
# [40000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(ds, test_size=0.2)

# %%
train
# Out:
#                                                 sentence label
# 14307  [ number variable + number number / number num...  good
# 17812  [ variable number variable - variable number -...  good
# 11020               ( number * ( variable ) ) - variable  good
# 15158  number * ( number ) / variable - number / [ nu...  good
# 4990   ( number + number - variable * / number ) + nu...   bad
# ...                                                  ...   ...
# 6265   [ variable number variable variable * / variab...  good
# 11284  variable - [ variable number variable variable...  good
# 18158  ( number * [ number number / variable + ] + / ...   bad
# 860    [ variable number number number number / + num...  good
# 15795  [ number variable - number - variable variable...  good
#
# [32000 rows x 2 columns]

# %%
#@title Save the distribution
train.to_csv('train.csv', sep=',', index=False, header=True, encoding='utf-8')
test.to_csv('test.csv', sep=',', index=False, header=True, encoding='utf-8')

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(ds)

dataset=dataset.train_test_split(test_size=0.2)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', '__index_level_0__'],
#         num_rows: 32000
#     })
#     test: Dataset({
#         features: ['sentence', 'label', '__index_level_0__'],
#         num_rows: 8000
#     })
# })

# %% [markdown]
# Import the dataset you'll be trainin on. This dataset has a 'text' field and a 'label' field. Be sure to tweak the script if you need to.

# %%
# from datasets import load_dataset, DatasetDict

# dataset = load_dataset("ilsilfverskiold/clickbait_titles_synthetic_data")
# dataset

# %% [markdown]
# Decide on your pre-trained model along with your new model's name.

# %%
model_name = "albert/albert-base-v2"
your_path = 'nomi'

# %% [markdown]
# Look over your distribution of the labels (optional)

# %%
from collections import Counter

train_label_distribution = Counter(dataset['train']['label'])
test_label_distribution = Counter(dataset['test']['label'])

print("Training Label Distribution:", train_label_distribution)
print("Test Label Distribution:", test_label_distribution)
# Out:
# Training Label Distribution: Counter({'bad': 16043, 'good': 15957})
# Test Label Distribution: Counter({'good': 4043, 'bad': 3957})

# %% [markdown]
# Create a label encoder that converts categorical labels to a standardized numerical format. Labels in their original categorical form (e.g., 'clickbait', 'factual') need to be converted into numerical values so that they can be processed by the algorithms.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

label_encoder.fit(dataset['train']['label'])

def encode_labels(example):
    return {'encoded_label': label_encoder.transform([example['label']])[0]}

for split in dataset:
    dataset[split] = dataset[split].map(encode_labels, batched=False)
# Out:
# Map:   0%|          | 0/32000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]

# %% [markdown]
# The id2label and label2id mappings in AutoConfig are used to inform the model of the specific label-to-ID mappings so we can get the actual label names rather than the numerical reps when we do inference with the model.

# %%
from transformers import AutoConfig

unique_labels = sorted(list(set(dataset['train']['label'])))
id2label = {i: label for i, label in enumerate(unique_labels)}
label2id = {label: i for i, label in enumerate(unique_labels)}

config = AutoConfig.from_pretrained(model_name)
config.id2label = id2label
config.label2id = label2id

# Verify the correct labels
print("ID to Label Mapping:", config.id2label)
print("Label to ID Mapping:", config.label2id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ID to Label Mapping: {0: 'bad', 1: 'good'}
# Label to ID Mapping: {'bad': 0, 'good': 1}

# %% [markdown]
# The provided code snippet is responsible for loading a tokenizer and a model from the Hugging Face Transformers library. Here we use ALBERT as a model, you can use AutoTokenizer and AutoModelForSequenceClassification if you want to use another model or it's specified tokenizer.

# %%
from transformers import AlbertForSequenceClassification, AlbertTokenizer

tokenizer = AlbertTokenizer.from_pretrained(model_name)
model = AlbertForSequenceClassification.from_pretrained(model_name, config=config)
# Out:
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert/albert-base-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#@title testing tokenizer
tokenizer("The quick brown fox jumped.")
# Out:
# {'input_ids': [2, 14, 2231, 886, 2385, 4298, 9, 3], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %% [markdown]
# This next function makes sure the text data is properly tokenized and labeled, preparing the dataset for efficient training of the transformer model.

# %%
def filter_invalid_content(example):
    return isinstance(example['sentence'], str)

dataset = dataset.filter(filter_invalid_content, batched=False)

def encode_data(batch):
    tokenized_inputs = tokenizer(batch["sentence"], padding=True, truncation=True, max_length=256)
    tokenized_inputs["labels"] = batch["encoded_label"]
    return tokenized_inputs

dataset_encoded = dataset.map(encode_data, batched=True)
dataset_encoded
# Out:
# Filter:   0%|          | 0/32000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/32000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', '__index_level_0__', 'encoded_label', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 32000
#     })
#     test: Dataset({
#         features: ['sentence', 'label', '__index_level_0__', 'encoded_label', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 8000
#     })
# })

# %%
dataset_encoded.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# The DataCollatorWithPadding ensures that all input sequences in a batch are padded to the same length, using the padding logic defined by the tokenizer.

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer)

# %% [markdown]
# Next we'll set up LabelEncoder to encode labels and defines a function to compute per-label accuracy from a confusion matrix, providing label-specific accuracy metrics. I.e. when we train the model we want to see the accuracy metrics per label as well as the average metrics. This is more relevant if you have more than two labels, and one is underperforming.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
import numpy as np

label_encoder = LabelEncoder()
label_encoder.fit(unique_labels)

def per_label_accuracy(y_true, y_pred, labels):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    correct_predictions = cm.diagonal()
    label_totals = cm.sum(axis=1)
    per_label_acc = np.divide(correct_predictions, label_totals, out=np.zeros_like(correct_predictions, dtype=float), where=label_totals != 0)
    return dict(zip(labels, per_label_acc))

# %% [markdown]
# Next we set up our compute metrics. Here I've set up several, but you may reduce them if needed be. You can read more on this metrics [here.](https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    decoded_labels = label_encoder.inverse_transform(labels)
    decoded_preds = label_encoder.inverse_transform(preds)

    precision = precision_score(decoded_labels, decoded_preds, average='weighted')
    recall = recall_score(decoded_labels, decoded_preds, average='weighted')
    f1 = f1_score(decoded_labels, decoded_preds, average='weighted')
    acc = accuracy_score(decoded_labels, decoded_preds)
    # cf = confusion_matrix(decoded_labels, decoded_preds)

    labels_list = list(label_encoder.classes_)
    per_label_acc = per_label_accuracy(decoded_labels, decoded_preds, labels_list)

    per_label_acc_metrics = {}
    for label, accuracy in per_label_acc.items():
        label_key = f"accuracy_label_{label}"
        per_label_acc_metrics[label_key] = accuracy

    return {
        # 'confusion': cf,
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        **per_label_acc_metrics
    }

# %% [markdown]
# Lastly, we set up our training metrics to train the model. I'm following the paper ["How to Fine-Tune BERT for Text Classification?"](https://arxiv.org/abs/1905.05583) on epochs, batch size and learning rate but do play around with it if you want to.
#
# When it is in training, be sure to look out for training loss and validation loss. Both should decrease consistently. If validation is increasing consistently you may be overfitting your model and you can try to decrease number of epochs.

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir=your_path,
    num_train_epochs=3,
    warmup_steps=500,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    logging_steps=10,
    evaluation_strategy='steps',
    eval_steps=100,
    learning_rate=2e-5,
    save_steps=1000,
    gradient_accumulation_steps=2
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_encoded['train'],
    eval_dataset=dataset_encoded['test'],
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='3000' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3000/3000 18:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Accuracy Label Bad</th>
#       <th>Accuracy Label Good</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.701200</td>
#       <td>0.690064</td>
#       <td>0.513250</td>
#       <td>0.435023</td>
#       <td>0.539252</td>
#       <td>0.513250</td>
#       <td>0.890321</td>
#       <td>0.144200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.676300</td>
#       <td>0.681943</td>
#       <td>0.542625</td>
#       <td>0.469067</td>
#       <td>0.585609</td>
#       <td>0.542625</td>
#       <td>0.167551</td>
#       <td>0.909721</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.525900</td>
#       <td>0.574049</td>
#       <td>0.700250</td>
#       <td>0.685996</td>
#       <td>0.740740</td>
#       <td>0.700250</td>
#       <td>0.487238</td>
#       <td>0.908731</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.521500</td>
#       <td>0.467941</td>
#       <td>0.769500</td>
#       <td>0.763313</td>
#       <td>0.798025</td>
#       <td>0.769500</td>
#       <td>0.609047</td>
#       <td>0.926540</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.486700</td>
#       <td>0.482924</td>
#       <td>0.773125</td>
#       <td>0.766098</td>
#       <td>0.807184</td>
#       <td>0.773125</td>
#       <td>0.600960</td>
#       <td>0.941628</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.406100</td>
#       <td>0.398077</td>
#       <td>0.816750</td>
#       <td>0.814554</td>
#       <td>0.830570</td>
#       <td>0.816750</td>
#       <td>0.710134</td>
#       <td>0.921098</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.386100</td>
#       <td>0.455768</td>
#       <td>0.803875</td>
#       <td>0.803867</td>
#       <td>0.804158</td>
#       <td>0.803875</td>
#       <td>0.815517</td>
#       <td>0.792481</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.348500</td>
#       <td>0.395029</td>
#       <td>0.817875</td>
#       <td>0.814633</td>
#       <td>0.839348</td>
#       <td>0.817875</td>
#       <td>0.687642</td>
#       <td>0.945338</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.369900</td>
#       <td>0.350817</td>
#       <td>0.844375</td>
#       <td>0.841976</td>
#       <td>0.864333</td>
#       <td>0.844375</td>
#       <td>0.723528</td>
#       <td>0.962651</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.395200</td>
#       <td>0.351705</td>
#       <td>0.846000</td>
#       <td>0.842048</td>
#       <td>0.881319</td>
#       <td>0.846000</td>
#       <td>0.689917</td>
#       <td>0.998763</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.335100</td>
#       <td>0.339471</td>
#       <td>0.851500</td>
#       <td>0.848098</td>
#       <td>0.883128</td>
#       <td>0.851500</td>
#       <td>0.704069</td>
#       <td>0.995795</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.313900</td>
#       <td>0.328573</td>
#       <td>0.853875</td>
#       <td>0.850487</td>
#       <td>0.886156</td>
#       <td>0.853875</td>
#       <td>0.705585</td>
#       <td>0.999011</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.318400</td>
#       <td>0.326341</td>
#       <td>0.854750</td>
#       <td>0.851591</td>
#       <td>0.884888</td>
#       <td>0.854750</td>
#       <td>0.711145</td>
#       <td>0.995301</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.360700</td>
#       <td>0.335661</td>
#       <td>0.845625</td>
#       <td>0.841605</td>
#       <td>0.881486</td>
#       <td>0.845625</td>
#       <td>0.688400</td>
#       <td>0.999505</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.320800</td>
#       <td>0.306756</td>
#       <td>0.866125</td>
#       <td>0.863733</td>
#       <td>0.891186</td>
#       <td>0.866125</td>
#       <td>0.736164</td>
#       <td>0.993322</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.267100</td>
#       <td>0.294165</td>
#       <td>0.874000</td>
#       <td>0.872021</td>
#       <td>0.896239</td>
#       <td>0.874000</td>
#       <td>0.752338</td>
#       <td>0.993074</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.301600</td>
#       <td>0.295216</td>
#       <td>0.880000</td>
#       <td>0.879137</td>
#       <td>0.889617</td>
#       <td>0.880000</td>
#       <td>0.798585</td>
#       <td>0.959683</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.281800</td>
#       <td>0.317805</td>
#       <td>0.867125</td>
#       <td>0.866144</td>
#       <td>0.876663</td>
#       <td>0.867125</td>
#       <td>0.784433</td>
#       <td>0.948058</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.223400</td>
#       <td>0.251043</td>
#       <td>0.903875</td>
#       <td>0.902992</td>
#       <td>0.917300</td>
#       <td>0.903875</td>
#       <td>0.811726</td>
#       <td>0.994064</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.219300</td>
#       <td>0.225237</td>
#       <td>0.916500</td>
#       <td>0.916025</td>
#       <td>0.924725</td>
#       <td>0.916500</td>
#       <td>0.844832</td>
#       <td>0.986644</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.215300</td>
#       <td>0.247993</td>
#       <td>0.901375</td>
#       <td>0.901267</td>
#       <td>0.902591</td>
#       <td>0.901375</td>
#       <td>0.871873</td>
#       <td>0.930250</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.257900</td>
#       <td>0.440221</td>
#       <td>0.808750</td>
#       <td>0.807559</td>
#       <td>0.818095</td>
#       <td>0.808750</td>
#       <td>0.891837</td>
#       <td>0.727430</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.248700</td>
#       <td>0.208568</td>
#       <td>0.927125</td>
#       <td>0.926801</td>
#       <td>0.933580</td>
#       <td>0.927125</td>
#       <td>0.864291</td>
#       <td>0.988622</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.221200</td>
#       <td>0.190339</td>
#       <td>0.937750</td>
#       <td>0.937659</td>
#       <td>0.939653</td>
#       <td>0.937750</td>
#       <td>0.903462</td>
#       <td>0.971308</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.169700</td>
#       <td>0.173704</td>
#       <td>0.946000</td>
#       <td>0.945846</td>
#       <td>0.950145</td>
#       <td>0.946000</td>
#       <td>0.896639</td>
#       <td>0.994311</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.222700</td>
#       <td>0.186995</td>
#       <td>0.942125</td>
#       <td>0.942049</td>
#       <td>0.943809</td>
#       <td>0.942125</td>
#       <td>0.910033</td>
#       <td>0.973535</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.157500</td>
#       <td>0.163523</td>
#       <td>0.950625</td>
#       <td>0.950516</td>
#       <td>0.953769</td>
#       <td>0.950625</td>
#       <td>0.907758</td>
#       <td>0.992580</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.160000</td>
#       <td>0.176255</td>
#       <td>0.946250</td>
#       <td>0.946144</td>
#       <td>0.948976</td>
#       <td>0.946250</td>
#       <td>0.905989</td>
#       <td>0.985654</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.116300</td>
#       <td>0.156306</td>
#       <td>0.954375</td>
#       <td>0.954266</td>
#       <td>0.957824</td>
#       <td>0.954375</td>
#       <td>0.909780</td>
#       <td>0.998021</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.188800</td>
#       <td>0.157212</td>
#       <td>0.954000</td>
#       <td>0.953888</td>
#       <td>0.957547</td>
#       <td>0.954000</td>
#       <td>0.908769</td>
#       <td>0.998269</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3000, training_loss=0.3416156885226568, metrics={'train_runtime': 1112.1644, 'train_samples_per_second': 86.318, 'train_steps_per_second': 2.697, 'total_flos': 328821450272640.0, 'train_loss': 0.3416156885226568, 'epoch': 3.0})

# %% [markdown]
# Once you're finito, you can evaluate the results, save your model and the state.

# %%
trainer.evaluate()
trainer.save_model(your_path)
trainer.save_state()
# Out:
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 00:16]
#     </div>

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='1000' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 00:32]
#     </div>
# {'eval_loss': 0.1572115123271942,
#  'eval_accuracy': 0.954,
#  'eval_f1': 0.9538877078161438,
#  'eval_precision': 0.9575470183762034,
#  'eval_recall': 0.954,
#  'eval_accuracy_label_bad': 0.9087692696487237,
#  'eval_accuracy_label_good': 0.9982686124165224,
#  'eval_runtime': 16.3612,
#  'eval_samples_per_second': 488.962,
#  'eval_steps_per_second': 30.56,
#  'epoch': 3.0}

# %% [markdown]
# If you want to test it out, you can run the pipeline directly with the model. I just used some new example titles to see how it did.

# %%
from transformers import pipeline
pipe = pipeline('text-classification', model='nomi')

# %%
example_titles = [
    "( [ variable variable variable - + ] + number / number - number )",
    "variable - variable * variable + variable / variable + [ variable ] * number + variable",
    "variable",
    "( [ number variable variable variable - / + variable variable number variable * * - number - variable * + variable / ] )",
    "number",
    "]",
    "number",
    "variable variable",
    "] variable",
    "variable / number - ( [ ) variable variable number / variable variable number + / number / / * ] )"
]

for title in example_titles:
    result = pipe(title)
    print(f"Title: {title}")
    print(f"Output: {result[0]['label']}")
# Out:
# Title: ( [ variable variable variable - + ] + number / number - number )
# Output: good
# Title: variable - variable * variable + variable / variable + [ variable ] * number + variable
# Output: good
# Title: variable
# Output: bad
# Title: ( [ number variable variable variable - / + variable variable number variable * * - number - variable * + variable / ] )
# Output: good
# Title: number
# Output: bad
# Title: ]
# Output: bad
# Title: number
# Output: bad
# Title: variable variable
# Output: bad
# Title: ] variable
# Output: bad
# Title: variable / number - ( [ ) variable variable number / variable variable number + / number / / * ] )
# Output: bad

# %% [markdown]
# If you're satisfied, you can log in to HuggingFace with a token (you'll find these in your account under Settings - make sure it has write access).

# %%
# !huggingface-cli login

# %% [markdown]
# Push the model with your new name for it. It usually just takes the name you set when you trained it so whatever you put here doesn't matter.

# %%
# tokenizer.push_to_hub("username/classify-clickbait")
# trainer.push_to_hub("username/classify-clickbait")

# %% [markdown]
# Now, you're done. You got your text classifier.

# %%
# !zip -r /content/nomi_model.zip /content/nomi
# Out:
#   adding: content/nomi/ (stored 0%)
#   adding: content/nomi/model.safetensors (deflated 7%)
#   adding: content/nomi/training_args.bin (deflated 51%)
#   adding: content/nomi/trainer_state.json (deflated 82%)
#   adding: content/nomi/runs/ (stored 0%)
#   adding: content/nomi/runs/Jun25_01-25-45_41e797489ec8/ (stored 0%)
#   adding: content/nomi/runs/Jun25_01-25-45_41e797489ec8/events.out.tfevents.1719278745.41e797489ec8.2725.0 (deflated 61%)
#   adding: content/nomi/runs/Jun25_01-26-58_41e797489ec8/ (stored 0%)
#   adding: content/nomi/runs/Jun25_01-26-58_41e797489ec8/events.out.tfevents.1719278818.41e797489ec8.2725.1 (deflated 68%)
#   adding: content/nomi/runs/Jun25_01-34-20_41e797489ec8/ (stored 0%)
#   adding: content/nomi/runs/Jun25_01-34-20_41e797489ec8/events.out.tfevents.1719279261.41e797489ec8.2725.2 (deflated 69%)
#   adding: content/nomi/runs/Jun25_01-34-20_41e797489ec8/events.out.tfevents.1719280389.41e797489ec8.2725.3 (deflated 53%)
#   adding: content/nomi/config.json (deflated 53%)
#   adding: content/nomi/special_tokens_map.json (deflated 49%)
#   adding: content/nomi/checkpoint-2000/ (stored 0%)
#   adding: content/nomi/checkpoint-2000/model.safetensors (deflated 7%)
#   adding: content/nomi/checkpoint-2000/training_args.bin (deflated 51%)
#   adding: content/nomi/checkpoint-2000/trainer_state.json (deflated 82%)
#   adding: content/nomi/checkpoint-2000/config.json (deflated 53%)
#   adding: content/nomi/checkpoint-2000/optimizer.pt (deflated 39%)
#   adding: content/nomi/checkpoint-2000/special_tokens_map.json (deflated 49%)
#   adding: content/nomi/checkpoint-2000/tokenizer_config.json (deflated 75%)
#   adding: content/nomi/checkpoint-2000/scheduler.pt (deflated 55%)
#   adding: content/nomi/checkpoint-2000/rng_state.pth (deflated 25%)
#   adding: content/nomi/checkpoint-2000/spiece.model (deflated 49%)
#   adding: content/nomi/tokenizer_config.json (deflated 75%)
#   adding: content/nomi/checkpoint-3000/ (stored 0%)
#   adding: content/nomi/checkpoint-3000/model.safetensors (deflated 7%)
#   adding: content/nomi/checkpoint-3000/training_args.bin (deflated 51%)
#   adding: content/nomi/checkpoint-3000/trainer_state.json (deflated 82%)
#   adding: content/nomi/checkpoint-3000/config.json (deflated 53%)
#   adding: content/nomi/checkpoint-3000/optimizer.pt (deflated 39%)
#   adding: content/nomi/checkpoint-3000/special_tokens_map.json (deflated 49%)
#   adding: content/nomi/checkpoint-3000/tokenizer_config.json (deflated 75%)
#   adding: content/nomi/checkpoint-3000/scheduler.pt (deflated 56%)
#   adding: content/nomi/checkpoint-3000/rng_state.pth (deflated 25%)
#   adding: content/nomi/checkpoint-3000/spiece.model (deflated 49%)
#   adding: content/nomi/spiece.model (deflated 49%)
#   adding: content/nomi/checkpoint-1000/ (stored 0%)
#   adding: content/nomi/checkpoint-1000/model.safetensors (deflated 7%)
#   adding: content/nomi/checkpoint-1000/training_args.bin (deflated 51%)
#   adding: content/nomi/checkpoint-1000/trainer_state.json (deflated 81%)
#   adding: content/nomi/checkpoint-1000/config.json (deflated 53%)
#   adding: content/nomi/checkpoint-1000/optimizer.pt (deflated 39%)
#   adding: content/nomi/checkpoint-1000/special_tokens_map.json (deflated 49%)
#   adding: content/nomi/checkpoint-1000/tokenizer_config.json (deflated 75%)
#   adding: content/nomi/checkpoint-1000/scheduler.pt (deflated 55%)
#   adding: content/nomi/checkpoint-1000/rng_state.pth (deflated 25%)
#   adding: content/nomi/checkpoint-1000/spiece.model (deflated 49%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming trainer.train() has been called and log history is available
log_history = trainer.state.log_history
log_history
# Out:
# [{'loss': 0.6975,
#   'grad_norm': 2.845897912979126,
#   'learning_rate': 4.0000000000000003e-07,
#   'epoch': 0.01,
#   'step': 10},
#  {'loss': 0.7233,
#   'grad_norm': 4.1713337898254395,
#   'learning_rate': 8.000000000000001e-07,
#   'epoch': 0.02,
#   'step': 20},
#  {'loss': 0.7085,
#   'grad_norm': 3.223047971725464,
#   'learning_rate': 1.2000000000000002e-06,
#   'epoch': 0.03,
#   'step': 30},
#  {'loss': 0.7093,
#   'grad_norm': 4.125215530395508,
#   'learning_rate': 1.6000000000000001e-06,
#   'epoch': 0.04,
#   'step': 40},
#  {'loss': 0.6812,
#   'grad_norm': 3.508023738861084,
#   'learning_rate': 2.0000000000000003e-06,
#   'epoch': 0.05,
#   'step': 50},
#  {'loss': 0.6962,
#   'grad_norm': 4.207041263580322,
#   'learning_rate': 2.4000000000000003e-06,
#   'epoch': 0.06,
#   'step': 60},
#  {'loss': 0.6891,
#   'grad_norm': 6.273722171783447,
#   'learning_rate': 2.8000000000000003e-06,
#   'epoch': 0.07,
#   'step': 70},
#  {'loss': 0.7023,
#   'grad_norm': 3.1793785095214844,
#   'learning_rate': 3.2000000000000003e-06,
#   'epoch': 0.08,
#   'step': 80},
#  {'loss': 0.6852,
#   'grad_norm': 5.249373912811279,
#   'learning_rate': 3.6000000000000003e-06,
#   'epoch': 0.09,
#   'step': 90},
#  {'loss': 0.7012,
#   'grad_norm': 12.836668968200684,
#   'learning_rate': 4.000000000000001e-06,
#   'epoch': 0.1,
#   'step': 100},
#  {'eval_loss': 0.6900637745857239,
#   'eval_accuracy': 0.51325,
#   'eval_f1': 0.43502341427549474,
#   'eval_precision': 0.5392523103587291,
#   'eval_recall': 0.51325,
#   'eval_accuracy_label_bad': 0.8903209502148092,
#   'eval_accuracy_label_good': 0.14419985159534998,
#   'eval_runtime': 16.6001,
#   'eval_samples_per_second': 481.925,
#   'eval_steps_per_second': 30.12,
#   'epoch': 0.1,
#   'step': 100},
#  {'loss': 0.684,
#   'grad_norm': 8.534713745117188,
#   'learning_rate': 4.4e-06,
#   'epoch': 0.11,
#   'step': 110},
#  {'loss': 0.7013,
#   'grad_norm': 10.214550971984863,
#   'learning_rate': 4.800000000000001e-06,
#   'epoch': 0.12,
#   'step': 120},
#  {'loss': 0.6837,
#   'grad_norm': 6.293008804321289,
#   'learning_rate': 5.2e-06,
#   'epoch': 0.13,
#   'step': 130},
#  {'loss': 0.6874,
#   'grad_norm': 10.2511568069458,
#   'learning_rate': 5.600000000000001e-06,
#   'epoch': 0.14,
#   'step': 140},
#  {'loss': 0.7005,
#   'grad_norm': 10.76247787475586,
#   'learning_rate': 6e-06,
#   'epoch': 0.15,
#   'step': 150},
#  {'loss': 0.6901,
#   'grad_norm': 10.71396541595459,
#   'learning_rate': 6.4000000000000006e-06,
#   'epoch': 0.16,
#   'step': 160},
#  {'loss': 0.6865,
#   'grad_norm': 7.7789130210876465,
#   'learning_rate': 6.800000000000001e-06,
#   'epoch': 0.17,
#   'step': 170},
#  {'loss': 0.6584,
#   'grad_norm': 7.371674537658691,
#   'learning_rate': 7.2000000000000005e-06,
#   'epoch': 0.18,
#   'step': 180},
#  {'loss': 0.6814,
#   'grad_norm': 8.608293533325195,
#   'learning_rate': 7.600000000000001e-06,
#   'epoch': 0.19,
#   'step': 190},
#  {'loss': 0.6763,
#   'grad_norm': 6.129601001739502,
#   'learning_rate': 8.000000000000001e-06,
#   'epoch': 0.2,
#   'step': 200},
#  {'eval_loss': 0.6819432377815247,
#   'eval_accuracy': 0.542625,
#   'eval_f1': 0.4690670789262932,
#   'eval_precision': 0.5856091396575741,
#   'eval_recall': 0.542625,
#   'eval_accuracy_label_bad': 0.16755117513267628,
#   'eval_accuracy_label_good': 0.90972050457581,
#   'eval_runtime': 16.081,
#   'eval_samples_per_second': 497.48,
#   'eval_steps_per_second': 31.093,
#   'epoch': 0.2,
#   'step': 200},
#  {'loss': 0.6627,
#   'grad_norm': 9.829499244689941,
#   'learning_rate': 8.400000000000001e-06,
#   'epoch': 0.21,
#   'step': 210},
#  {'loss': 0.613,
#   'grad_norm': 14.193357467651367,
#   'learning_rate': 8.8e-06,
#   'epoch': 0.22,
#   'step': 220},
#  {'loss': 0.5948,
#   'grad_norm': 8.580907821655273,
#   'learning_rate': 9.200000000000002e-06,
#   'epoch': 0.23,
#   'step': 230},
#  {'loss': 0.6065,
#   'grad_norm': 33.58790969848633,
#   'learning_rate': 9.600000000000001e-06,
#   'epoch': 0.24,
#   'step': 240},
#  {'loss': 0.5951,
#   'grad_norm': 20.061948776245117,
#   'learning_rate': 1e-05,
#   'epoch': 0.25,
#   'step': 250},
#  {'loss': 0.5715,
#   'grad_norm': 12.815431594848633,
#   'learning_rate': 1.04e-05,
#   'epoch': 0.26,
#   'step': 260},
#  {'loss': 0.5794,
#   'grad_norm': 24.501155853271484,
#   'learning_rate': 1.0800000000000002e-05,
#   'epoch': 0.27,
#   'step': 270},
#  {'loss': 0.6135,
#   'grad_norm': 13.210712432861328,
#   'learning_rate': 1.1200000000000001e-05,
#   'epoch': 0.28,
#   'step': 280},
#  {'loss': 0.5621,
#   'grad_norm': 54.14091491699219,
#   'learning_rate': 1.16e-05,
#   'epoch': 0.29,
#   'step': 290},
#  {'loss': 0.5259,
#   'grad_norm': 9.683616638183594,
#   'learning_rate': 1.2e-05,
#   'epoch': 0.3,
#   'step': 300},
#  {'eval_loss': 0.5740489363670349,
#   'eval_accuracy': 0.70025,
#   'eval_f1': 0.6859963124277663,
#   'eval_precision': 0.7407401685072685,
#   'eval_recall': 0.70025,
#   'eval_accuracy_label_bad': 0.48723780641900427,
#   'eval_accuracy_label_good': 0.9087311402423942,
#   'eval_runtime': 16.1471,
#   'eval_samples_per_second': 495.446,
#   'eval_steps_per_second': 30.965,
#   'epoch': 0.3,
#   'step': 300},
#  {'loss': 0.5835,
#   'grad_norm': 12.598222732543945,
#   'learning_rate': 1.2400000000000002e-05,
#   'epoch': 0.31,
#   'step': 310},
#  {'loss': 0.6929,
#   'grad_norm': 43.34273147583008,
#   'learning_rate': 1.2800000000000001e-05,
#   'epoch': 0.32,
#   'step': 320},
#  {'loss': 0.6611,
#   'grad_norm': 12.076387405395508,
#   'learning_rate': 1.3200000000000002e-05,
#   'epoch': 0.33,
#   'step': 330},
#  {'loss': 0.5929,
#   'grad_norm': 8.788152694702148,
#   'learning_rate': 1.3600000000000002e-05,
#   'epoch': 0.34,
#   'step': 340},
#  {'loss': 0.5592,
#   'grad_norm': 8.152222633361816,
#   'learning_rate': 1.4e-05,
#   'epoch': 0.35,
#   'step': 350},
#  {'loss': 0.5339,
#   'grad_norm': 13.613580703735352,
#   'learning_rate': 1.4400000000000001e-05,
#   'epoch': 0.36,
#   'step': 360},
#  {'loss': 0.5196,
#   'grad_norm': 53.11878967285156,
#   'learning_rate': 1.48e-05,
#   'epoch': 0.37,
#   'step': 370},
#  {'loss': 0.5902,
#   'grad_norm': 33.59728240966797,
#   'learning_rate': 1.5200000000000002e-05,
#   'epoch': 0.38,
#   'step': 380},
#  {'loss': 0.5346,
#   'grad_norm': 36.53604507446289,
#   'learning_rate': 1.5600000000000003e-05,
#   'epoch': 0.39,
#   'step': 390},
#  {'loss': 0.5215,
#   'grad_norm': 9.882640838623047,
#   'learning_rate': 1.6000000000000003e-05,
#   'epoch': 0.4,
#   'step': 400},
#  {'eval_loss': 0.46794113516807556,
#   'eval_accuracy': 0.7695,
#   'eval_f1': 0.7633128368313905,
#   'eval_precision': 0.798024572012118,
#   'eval_recall': 0.7695,
#   'eval_accuracy_label_bad': 0.6090472580237554,
#   'eval_accuracy_label_good': 0.9265396982438783,
#   'eval_runtime': 16.3547,
#   'eval_samples_per_second': 489.156,
#   'eval_steps_per_second': 30.572,
#   'epoch': 0.4,
#   'step': 400},
#  {'loss': 0.5032,
#   'grad_norm': 14.060458183288574,
#   'learning_rate': 1.64e-05,
#   'epoch': 0.41,
#   'step': 410},
#  {'loss': 0.4956,
#   'grad_norm': 40.871002197265625,
#   'learning_rate': 1.6800000000000002e-05,
#   'epoch': 0.42,
#   'step': 420},
#  {'loss': 0.4798,
#   'grad_norm': 10.23838996887207,
#   'learning_rate': 1.72e-05,
#   'epoch': 0.43,
#   'step': 430},
#  {'loss': 0.5949,
#   'grad_norm': 15.134390830993652,
#   'learning_rate': 1.76e-05,
#   'epoch': 0.44,
#   'step': 440},
#  {'loss': 0.4521,
#   'grad_norm': 46.64689254760742,
#   'learning_rate': 1.8e-05,
#   'epoch': 0.45,
#   'step': 450},
#  {'loss': 0.4908,
#   'grad_norm': 14.838714599609375,
#   'learning_rate': 1.8400000000000003e-05,
#   'epoch': 0.46,
#   'step': 460},
#  {'loss': 0.4855,
#   'grad_norm': 60.93636703491211,
#   'learning_rate': 1.88e-05,
#   'epoch': 0.47,
#   'step': 470},
#  {'loss': 0.4579,
#   'grad_norm': 33.32231140136719,
#   'learning_rate': 1.9200000000000003e-05,
#   'epoch': 0.48,
#   'step': 480},
#  {'loss': 0.4794,
#   'grad_norm': 4.558327674865723,
#   'learning_rate': 1.9600000000000002e-05,
#   'epoch': 0.49,
#   'step': 490},
#  {'loss': 0.4867,
#   'grad_norm': 55.505062103271484,
#   'learning_rate': 2e-05,
#   'epoch': 0.5,
#   'step': 500},
#  {'eval_loss': 0.4829242527484894,
#   'eval_accuracy': 0.773125,
#   'eval_f1': 0.7660975497312621,
#   'eval_precision': 0.8071842153216237,
#   'eval_recall': 0.773125,
#   'eval_accuracy_label_bad': 0.6009603234773818,
#   'eval_accuracy_label_good': 0.941627504328469,
#   'eval_runtime': 16.1247,
#   'eval_samples_per_second': 496.132,
#   'eval_steps_per_second': 31.008,
#   'epoch': 0.5,
#   'step': 500},
#  {'loss': 0.535,
#   'grad_norm': 17.77093505859375,
#   'learning_rate': 1.9920000000000002e-05,
#   'epoch': 0.51,
#   'step': 510},
#  {'loss': 0.4714,
#   'grad_norm': 57.76066970825195,
#   'learning_rate': 1.9840000000000003e-05,
#   'epoch': 0.52,
#   'step': 520},
#  {'loss': 0.4629,
#   'grad_norm': 18.478931427001953,
#   'learning_rate': 1.976e-05,
#   'epoch': 0.53,
#   'step': 530},
#  {'loss': 0.6845,
#   'grad_norm': 174.337646484375,
#   'learning_rate': 1.968e-05,
#   'epoch': 0.54,
#   'step': 540},
#  {'loss': 0.5256,
#   'grad_norm': 37.976463317871094,
#   'learning_rate': 1.9600000000000002e-05,
#   'epoch': 0.55,
#   'step': 550},
#  {'loss': 0.5434,
#   'grad_norm': 22.20747184753418,
#   'learning_rate': 1.9520000000000003e-05,
#   'epoch': 0.56,
#   'step': 560},
#  {'loss': 0.594,
#   'grad_norm': 9.821788787841797,
#   'learning_rate': 1.944e-05,
#   'epoch': 0.57,
#   'step': 570},
#  {'loss': 0.4702,
#   'grad_norm': 7.992551326751709,
#   'learning_rate': 1.936e-05,
#   'epoch': 0.58,
#   'step': 580},
#  {'loss': 0.4458,
#   'grad_norm': 7.490342140197754,
#   'learning_rate': 1.9280000000000002e-05,
#   'epoch': 0.59,
#   'step': 590},
#  {'loss': 0.4061,
#   'grad_norm': 12.348076820373535,
#   'learning_rate': 1.9200000000000003e-05,
#   'epoch': 0.6,
#   'step': 600},
#  {'eval_loss': 0.3980772793292999,
#   'eval_accuracy': 0.81675,
#   'eval_f1': 0.8145544327801058,
#   'eval_precision': 0.8305699158618336,
#   'eval_recall': 0.81675,
#   'eval_accuracy_label_bad': 0.7101339398534243,
#   'eval_accuracy_label_good': 0.9210981944100916,
#   'eval_runtime': 16.1767,
#   'eval_samples_per_second': 494.54,
#   'eval_steps_per_second': 30.909,
#   'epoch': 0.6,
#   'step': 600},
#  {'loss': 0.3542,
#   'grad_norm': 7.499828815460205,
#   'learning_rate': 1.912e-05,
#   'epoch': 0.61,
#   'step': 610},
#  {'loss': 0.3579,
#   'grad_norm': 50.39945983886719,
#   'learning_rate': 1.904e-05,
#   'epoch': 0.62,
#   'step': 620},
#  {'loss': 0.387,
#   'grad_norm': 5.687309741973877,
#   'learning_rate': 1.896e-05,
#   'epoch': 0.63,
#   'step': 630},
#  {'loss': 0.3586,
#   'grad_norm': 7.56859016418457,
#   'learning_rate': 1.8880000000000002e-05,
#   'epoch': 0.64,
#   'step': 640},
#  {'loss': 0.3935,
#   'grad_norm': 61.952083587646484,
#   'learning_rate': 1.88e-05,
#   'epoch': 0.65,
#   'step': 650},
#  {'loss': 0.4344,
#   'grad_norm': 9.125776290893555,
#   'learning_rate': 1.8720000000000004e-05,
#   'epoch': 0.66,
#   'step': 660},
#  {'loss': 0.354,
#   'grad_norm': 21.80046844482422,
#   'learning_rate': 1.864e-05,
#   'epoch': 0.67,
#   'step': 670},
#  {'loss': 0.3448,
#   'grad_norm': 3.8999297618865967,
#   'learning_rate': 1.8560000000000002e-05,
#   'epoch': 0.68,
#   'step': 680},
#  {'loss': 0.3504,
#   'grad_norm': 14.603804588317871,
#   'learning_rate': 1.8480000000000003e-05,
#   'epoch': 0.69,
#   'step': 690},
#  {'loss': 0.3861,
#   'grad_norm': 15.130375862121582,
#   'learning_rate': 1.8400000000000003e-05,
#   'epoch': 0.7,
#   'step': 700},
#  {'eval_loss': 0.4557681381702423,
#   'eval_accuracy': 0.803875,
#   'eval_f1': 0.8038673173525137,
#   'eval_precision': 0.8041581756414433,
#   'eval_recall': 0.803875,
#   'eval_accuracy_label_bad': 0.8155168056608542,
#   'eval_accuracy_label_good': 0.7924808310660401,
#   'eval_runtime': 16.2058,
#   'eval_samples_per_second': 493.65,
#   'eval_steps_per_second': 30.853,
#   'epoch': 0.7,
#   'step': 700},
#  {'loss': 0.3407,
#   'grad_norm': 4.965668201446533,
#   'learning_rate': 1.832e-05,
#   'epoch': 0.71,
#   'step': 710},
#  {'loss': 0.3581,
#   'grad_norm': 12.316312789916992,
#   'learning_rate': 1.824e-05,
#   'epoch': 0.72,
#   'step': 720},
#  {'loss': 0.373,
#   'grad_norm': 14.39039421081543,
#   'learning_rate': 1.8160000000000002e-05,
#   'epoch': 0.73,
#   'step': 730},
#  {'loss': 0.5972,
#   'grad_norm': 11.148295402526855,
#   'learning_rate': 1.8080000000000003e-05,
#   'epoch': 0.74,
#   'step': 740},
#  {'loss': 0.4895,
#   'grad_norm': 118.94562530517578,
#   'learning_rate': 1.8e-05,
#   'epoch': 0.75,
#   'step': 750},
#  {'loss': 0.5587,
#   'grad_norm': 20.691944122314453,
#   'learning_rate': 1.792e-05,
#   'epoch': 0.76,
#   'step': 760},
#  {'loss': 0.4844,
#   'grad_norm': 9.98434829711914,
#   'learning_rate': 1.7840000000000002e-05,
#   'epoch': 0.77,
#   'step': 770},
#  {'loss': 0.4014,
#   'grad_norm': 14.887662887573242,
#   'learning_rate': 1.7760000000000003e-05,
#   'epoch': 0.78,
#   'step': 780},
#  {'loss': 0.3972,
#   'grad_norm': 8.2715425491333,
#   'learning_rate': 1.768e-05,
#   'epoch': 0.79,
#   'step': 790},
#  {'loss': 0.3485,
#   'grad_norm': 9.782246589660645,
#   'learning_rate': 1.76e-05,
#   'epoch': 0.8,
#   'step': 800},
#  {'eval_loss': 0.39502933621406555,
#   'eval_accuracy': 0.817875,
#   'eval_f1': 0.8146334877537275,
#   'eval_precision': 0.8393481363800579,
#   'eval_recall': 0.817875,
#   'eval_accuracy_label_bad': 0.6876421531463229,
#   'eval_accuracy_label_good': 0.9453376205787781,
#   'eval_runtime': 16.1656,
#   'eval_samples_per_second': 494.879,
#   'eval_steps_per_second': 30.93,
#   'epoch': 0.8,
#   'step': 800},
#  {'loss': 0.3756,
#   'grad_norm': 8.984137535095215,
#   'learning_rate': 1.752e-05,
#   'epoch': 0.81,
#   'step': 810},
#  {'loss': 0.3871,
#   'grad_norm': 3.9944119453430176,
#   'learning_rate': 1.7440000000000002e-05,
#   'epoch': 0.82,
#   'step': 820},
#  {'loss': 0.3712,
#   'grad_norm': 10.245388984680176,
#   'learning_rate': 1.736e-05,
#   'epoch': 0.83,
#   'step': 830},
#  {'loss': 0.378,
#   'grad_norm': 22.58536148071289,
#   'learning_rate': 1.728e-05,
#   'epoch': 0.84,
#   'step': 840},
#  {'loss': 0.4057,
#   'grad_norm': 23.328271865844727,
#   'learning_rate': 1.72e-05,
#   'epoch': 0.85,
#   'step': 850},
#  {'loss': 0.3494,
#   'grad_norm': 4.804591178894043,
#   'learning_rate': 1.7120000000000002e-05,
#   'epoch': 0.86,
#   'step': 860},
#  {'loss': 0.5264,
#   'grad_norm': 6.764691352844238,
#   'learning_rate': 1.704e-05,
#   'epoch': 0.87,
#   'step': 870},
#  {'loss': 0.3074,
#   'grad_norm': 16.7683162689209,
#   'learning_rate': 1.696e-05,
#   'epoch': 0.88,
#   'step': 880},
#  {'loss': 0.384,
#   'grad_norm': 3.064012050628662,
#   'learning_rate': 1.688e-05,
#   'epoch': 0.89,
#   'step': 890},
#  {'loss': 0.3699,
#   'grad_norm': 29.105209350585938,
#   'learning_rate': 1.6800000000000002e-05,
#   'epoch': 0.9,
#   'step': 900},
#  {'eval_loss': 0.35081711411476135,
#   'eval_accuracy': 0.844375,
#   'eval_f1': 0.8419757710332281,
#   'eval_precision': 0.864332984962407,
#   'eval_recall': 0.844375,
#   'eval_accuracy_label_bad': 0.7235279251958554,
#   'eval_accuracy_label_good': 0.9626514964135543,
#   'eval_runtime': 16.1671,
#   'eval_samples_per_second': 494.832,
#   'eval_steps_per_second': 30.927,
#   'epoch': 0.9,
#   'step': 900},
#  {'loss': 0.3716,
#   'grad_norm': 6.703898906707764,
#   'learning_rate': 1.672e-05,
#   'epoch': 0.91,
#   'step': 910},
#  {'loss': 0.2947,
#   'grad_norm': 3.9461252689361572,
#   'learning_rate': 1.664e-05,
#   'epoch': 0.92,
#   'step': 920},
#  {'loss': 0.3074,
#   'grad_norm': 7.054285526275635,
#   'learning_rate': 1.656e-05,
#   'epoch': 0.93,
#   'step': 930},
#  {'loss': 0.3796,
#   'grad_norm': 30.815425872802734,
#   'learning_rate': 1.648e-05,
#   'epoch': 0.94,
#   'step': 940},
#  {'loss': 0.3307,
#   'grad_norm': 5.091451644897461,
#   'learning_rate': 1.64e-05,
#   'epoch': 0.95,
#   'step': 950},
#  {'loss': 0.424,
#   'grad_norm': 23.112180709838867,
#   'learning_rate': 1.632e-05,
#   'epoch': 0.96,
#   'step': 960},
#  {'loss': 0.3396,
#   'grad_norm': 2.9026267528533936,
#   'learning_rate': 1.6240000000000004e-05,
#   'epoch': 0.97,
#   'step': 970},
#  {'loss': 0.3933,
#   'grad_norm': 18.422088623046875,
#   'learning_rate': 1.616e-05,
#   'epoch': 0.98,
#   'step': 980},
#  {'loss': 0.3789,
#   'grad_norm': 8.268654823303223,
#   'learning_rate': 1.6080000000000002e-05,
#   'epoch': 0.99,
#   'step': 990},
#  {'loss': 0.3952,
#   'grad_norm': 8.366874694824219,
#   'learning_rate': 1.6000000000000003e-05,
#   'epoch': 1.0,
#   'step': 1000},
#  {'eval_loss': 0.35170483589172363,
#   'eval_accuracy': 0.846,
#   'eval_f1': 0.8420482690914192,
#   'eval_precision': 0.8813188976911098,
#   'eval_recall': 0.846,
#   'eval_accuracy_label_bad': 0.6899166034874905,
#   'eval_accuracy_label_good': 0.9987632945832303,
#   'eval_runtime': 16.1467,
#   'eval_samples_per_second': 495.458,
#   'eval_steps_per_second': 30.966,
#   'epoch': 1.0,
#   'step': 1000},
#  {'loss': 0.4258,
#   'grad_norm': 31.44792938232422,
#   'learning_rate': 1.5920000000000003e-05,
#   'epoch': 1.01,
#   'step': 1010},
#  {'loss': 0.4769,
#   'grad_norm': 3.002537488937378,
#   'learning_rate': 1.584e-05,
#   'epoch': 1.02,
#   'step': 1020},
#  {'loss': 0.4773,
#   'grad_norm': 11.217703819274902,
#   'learning_rate': 1.576e-05,
#   'epoch': 1.03,
#   'step': 1030},
#  {'loss': 0.3946,
#   'grad_norm': 2.968148946762085,
#   'learning_rate': 1.5680000000000002e-05,
#   'epoch': 1.04,
#   'step': 1040},
#  {'loss': 0.3024,
#   'grad_norm': 2.709444999694824,
#   'learning_rate': 1.5600000000000003e-05,
#   'epoch': 1.05,
#   'step': 1050},
#  {'loss': 0.3962,
#   'grad_norm': 4.476653575897217,
#   'learning_rate': 1.552e-05,
#   'epoch': 1.06,
#   'step': 1060},
#  {'loss': 0.4147,
#   'grad_norm': 64.76838684082031,
#   'learning_rate': 1.544e-05,
#   'epoch': 1.07,
#   'step': 1070},
#  {'loss': 0.3772,
#   'grad_norm': 5.902191162109375,
#   'learning_rate': 1.5360000000000002e-05,
#   'epoch': 1.08,
#   'step': 1080},
#  {'loss': 0.3319,
#   'grad_norm': 3.634805202484131,
#   'learning_rate': 1.5280000000000003e-05,
#   'epoch': 1.09,
#   'step': 1090},
#  {'loss': 0.3351,
#   'grad_norm': 2.9287877082824707,
#   'learning_rate': 1.5200000000000002e-05,
#   'epoch': 1.1,
#   'step': 1100},
#  {'eval_loss': 0.3394714891910553,
#   'eval_accuracy': 0.8515,
#   'eval_f1': 0.8480979923922232,
#   'eval_precision': 0.8831278757517492,
#   'eval_recall': 0.8515,
#   'eval_accuracy_label_bad': 0.7040687389436442,
#   'eval_accuracy_label_good': 0.995795201582983,
#   'eval_runtime': 16.2185,
#   'eval_samples_per_second': 493.263,
#   'eval_steps_per_second': 30.829,
#   'epoch': 1.1,
#   'step': 1100},
#  {'loss': 0.3238,
#   'grad_norm': 16.887765884399414,
#   'learning_rate': 1.5120000000000001e-05,
#   'epoch': 1.11,
#   'step': 1110},
#  {'loss': 0.3461,
#   'grad_norm': 4.016268730163574,
#   'learning_rate': 1.5040000000000002e-05,
#   'epoch': 1.12,
#   'step': 1120},
#  {'loss': 0.3399,
#   'grad_norm': 2.8619205951690674,
#   'learning_rate': 1.496e-05,
#   'epoch': 1.13,
#   'step': 1130},
#  {'loss': 0.3479,
#   'grad_norm': 5.991478443145752,
#   'learning_rate': 1.4880000000000002e-05,
#   'epoch': 1.1400000000000001,
#   'step': 1140},
#  {'loss': 0.3422,
#   'grad_norm': 13.283746719360352,
#   'learning_rate': 1.48e-05,
#   'epoch': 1.15,
#   'step': 1150},
#  {'loss': 0.4059,
#   'grad_norm': 90.07227325439453,
#   'learning_rate': 1.4720000000000001e-05,
#   'epoch': 1.16,
#   'step': 1160},
#  {'loss': 0.3742,
#   'grad_norm': 4.984657287597656,
#   'learning_rate': 1.464e-05,
#   'epoch': 1.17,
#   'step': 1170},
#  {'loss': 0.2992,
#   'grad_norm': 2.0625579357147217,
#   'learning_rate': 1.4560000000000001e-05,
#   'epoch': 1.18,
#   'step': 1180},
#  {'loss': 0.3198,
#   'grad_norm': 2.4366421699523926,
#   'learning_rate': 1.448e-05,
#   'epoch': 1.19,
#   'step': 1190},
#  {'loss': 0.3139,
#   'grad_norm': 3.133216381072998,
#   'learning_rate': 1.4400000000000001e-05,
#   'epoch': 1.2,
#   'step': 1200},
#  {'eval_loss': 0.3285730481147766,
#   'eval_accuracy': 0.853875,
#   'eval_f1': 0.8504871389484226,
#   'eval_precision': 0.8861559724815511,
#   'eval_recall': 0.853875,
#   'eval_accuracy_label_bad': 0.7055850391710892,
#   'eval_accuracy_label_good': 0.9990106356665842,
#   'eval_runtime': 16.1778,
#   'eval_samples_per_second': 494.504,
#   'eval_steps_per_second': 30.907,
#   'epoch': 1.2,
#   'step': 1200},
#  {'loss': 0.3533,
#   'grad_norm': 35.14282989501953,
#   'learning_rate': 1.432e-05,
#   'epoch': 1.21,
#   'step': 1210},
#  {'loss': 0.3977,
#   'grad_norm': 62.6181526184082,
#   'learning_rate': 1.4240000000000001e-05,
#   'epoch': 1.22,
#   'step': 1220},
#  {'loss': 0.3644,
#   'grad_norm': 8.894248008728027,
#   'learning_rate': 1.416e-05,
#   'epoch': 1.23,
#   'step': 1230},
#  {'loss': 0.3676,
#   'grad_norm': 5.43578577041626,
#   'learning_rate': 1.408e-05,
#   'epoch': 1.24,
#   'step': 1240},
#  {'loss': 0.4394,
#   'grad_norm': 6.410416603088379,
#   'learning_rate': 1.4e-05,
#   'epoch': 1.25,
#   'step': 1250},
#  {'loss': 0.3375,
#   'grad_norm': 2.2616899013519287,
#   'learning_rate': 1.392e-05,
#   'epoch': 1.26,
#   'step': 1260},
#  {'loss': 0.3439,
#   'grad_norm': 2.3473610877990723,
#   'learning_rate': 1.384e-05,
#   'epoch': 1.27,
#   'step': 1270},
#  {'loss': 0.3386,
#   'grad_norm': 5.208503723144531,
#   'learning_rate': 1.376e-05,
#   'epoch': 1.28,
#   'step': 1280},
#  {'loss': 0.3622,
#   'grad_norm': 83.45330047607422,
#   'learning_rate': 1.3680000000000003e-05,
#   'epoch': 1.29,
#   'step': 1290},
#  {'loss': 0.3184,
#   'grad_norm': 2.364088296890259,
#   'learning_rate': 1.3600000000000002e-05,
#   'epoch': 1.3,
#   'step': 1300},
#  {'eval_loss': 0.3263408839702606,
#   'eval_accuracy': 0.85475,
#   'eval_f1': 0.8515910815227733,
#   'eval_precision': 0.8848879333030061,
#   'eval_recall': 0.85475,
#   'eval_accuracy_label_bad': 0.711144806671721,
#   'eval_accuracy_label_good': 0.9953005194162751,
#   'eval_runtime': 16.1915,
#   'eval_samples_per_second': 494.086,
#   'eval_steps_per_second': 30.88,
#   'epoch': 1.3,
#   'step': 1300},
#  {'loss': 0.3451,
#   'grad_norm': 3.8157379627227783,
#   'learning_rate': 1.3520000000000003e-05,
#   'epoch': 1.31,
#   'step': 1310},
#  {'loss': 0.267,
#   'grad_norm': 2.3604373931884766,
#   'learning_rate': 1.3440000000000002e-05,
#   'epoch': 1.32,
#   'step': 1320},
#  {'loss': 0.3396,
#   'grad_norm': 2.080780029296875,
#   'learning_rate': 1.3360000000000003e-05,
#   'epoch': 1.33,
#   'step': 1330},
#  {'loss': 0.2825,
#   'grad_norm': 2.1805198192596436,
#   'learning_rate': 1.3280000000000002e-05,
#   'epoch': 1.34,
#   'step': 1340},
#  {'loss': 0.3675,
#   'grad_norm': 5.969290733337402,
#   'learning_rate': 1.3200000000000002e-05,
#   'epoch': 1.35,
#   'step': 1350},
#  {'loss': 0.311,
#   'grad_norm': 2.5539979934692383,
#   'learning_rate': 1.3120000000000001e-05,
#   'epoch': 1.3599999999999999,
#   'step': 1360},
#  {'loss': 0.3078,
#   'grad_norm': 3.5742433071136475,
#   'learning_rate': 1.3040000000000002e-05,
#   'epoch': 1.37,
#   'step': 1370},
#  {'loss': 0.3716,
#   'grad_norm': 4.762221813201904,
#   'learning_rate': 1.2960000000000001e-05,
#   'epoch': 1.38,
#   'step': 1380},
#  {'loss': 0.4226,
#   'grad_norm': 33.0945930480957,
#   'learning_rate': 1.2880000000000002e-05,
#   'epoch': 1.3900000000000001,
#   'step': 1390},
#  {'loss': 0.3607,
#   'grad_norm': 3.734999656677246,
#   'learning_rate': 1.2800000000000001e-05,
#   'epoch': 1.4,
#   'step': 1400},
#  {'eval_loss': 0.3356606960296631,
#   'eval_accuracy': 0.845625,
#   'eval_f1': 0.8416054888114545,
#   'eval_precision': 0.8814862950690983,
#   'eval_recall': 0.845625,
#   'eval_accuracy_label_bad': 0.6884003032600455,
#   'eval_accuracy_label_good': 0.9995053178332921,
#   'eval_runtime': 16.1681,
#   'eval_samples_per_second': 494.801,
#   'eval_steps_per_second': 30.925,
#   'epoch': 1.4,
#   'step': 1400},
#  {'loss': 0.297,
#   'grad_norm': 2.1135008335113525,
#   'learning_rate': 1.2720000000000002e-05,
#   'epoch': 1.41,
#   'step': 1410},
#  {'loss': 0.3493,
#   'grad_norm': 7.296887397766113,
#   'learning_rate': 1.2640000000000001e-05,
#   'epoch': 1.42,
#   'step': 1420},
#  {'loss': 0.3054,
#   'grad_norm': 7.669890880584717,
#   'learning_rate': 1.2560000000000002e-05,
#   'epoch': 1.43,
#   'step': 1430},
#  {'loss': 0.3102,
#   'grad_norm': 10.541513442993164,
#   'learning_rate': 1.248e-05,
#   'epoch': 1.44,
#   'step': 1440},
#  {'loss': 0.3336,
#   'grad_norm': 15.1976957321167,
#   'learning_rate': 1.2400000000000002e-05,
#   'epoch': 1.45,
#   'step': 1450},
#  {'loss': 0.2976,
#   'grad_norm': 10.421348571777344,
#   'learning_rate': 1.232e-05,
#   'epoch': 1.46,
#   'step': 1460},
#  {'loss': 0.3641,
#   'grad_norm': 3.8385303020477295,
#   'learning_rate': 1.2240000000000001e-05,
#   'epoch': 1.47,
#   'step': 1470},
#  {'loss': 0.3053,
#   'grad_norm': 15.20787239074707,
#   'learning_rate': 1.216e-05,
#   'epoch': 1.48,
#   'step': 1480},
#  {'loss': 0.3179,
#   'grad_norm': 10.337058067321777,
#   'learning_rate': 1.2080000000000001e-05,
#   'epoch': 1.49,
#   'step': 1490},
#  {'loss': 0.3208,
#   'grad_norm': 5.301661491394043,
#   'learning_rate': 1.2e-05,
#   'epoch': 1.5,
#   'step': 1500},
#  {'eval_loss': 0.30675622820854187,
#   'eval_accuracy': 0.866125,
#   'eval_f1': 0.8637330550487469,
#   'eval_precision': 0.8911864780793741,
#   'eval_recall': 0.866125,
#   'eval_accuracy_label_bad': 0.7361637604245641,
#   'eval_accuracy_label_good': 0.9933217907494435,
#   'eval_runtime': 16.2193,
#   'eval_samples_per_second': 493.24,
#   'eval_steps_per_second': 30.827,
#   'epoch': 1.5,
#   'step': 1500},
#  {'loss': 0.3104,
#   'grad_norm': 7.261610507965088,
#   'learning_rate': 1.1920000000000001e-05,
#   'epoch': 1.51,
#   'step': 1510},
#  {'loss': 0.3621,
#   'grad_norm': 14.273032188415527,
#   'learning_rate': 1.184e-05,
#   'epoch': 1.52,
#   'step': 1520},
#  {'loss': 0.328,
#   'grad_norm': 4.8806633949279785,
#   'learning_rate': 1.1760000000000001e-05,
#   'epoch': 1.53,
#   'step': 1530},
#  {'loss': 0.4328,
#   'grad_norm': 4.545321941375732,
#   'learning_rate': 1.168e-05,
#   'epoch': 1.54,
#   'step': 1540},
#  {'loss': 0.3525,
#   'grad_norm': 2.128540277481079,
#   'learning_rate': 1.16e-05,
#   'epoch': 1.55,
#   'step': 1550},
#  {'loss': 0.2708,
#   'grad_norm': 1.7505327463150024,
#   'learning_rate': 1.152e-05,
#   'epoch': 1.56,
#   'step': 1560},
#  {'loss': 0.2856,
#   'grad_norm': 114.09516906738281,
#   'learning_rate': 1.144e-05,
#   'epoch': 1.5699999999999998,
#   'step': 1570},
#  {'loss': 0.2851,
#   'grad_norm': 5.066189765930176,
#   'learning_rate': 1.136e-05,
#   'epoch': 1.58,
#   'step': 1580},
#  {'loss': 0.2998,
#   'grad_norm': 3.6320626735687256,
#   'learning_rate': 1.128e-05,
#   'epoch': 1.5899999999999999,
#   'step': 1590},
#  {'loss': 0.2671,
#   'grad_norm': 2.24167799949646,
#   'learning_rate': 1.1200000000000001e-05,
#   'epoch': 1.6,
#   'step': 1600},
#  {'eval_loss': 0.29416462779045105,
#   'eval_accuracy': 0.874,
#   'eval_f1': 0.8720212155399409,
#   'eval_precision': 0.89623852871174,
#   'eval_recall': 0.874,
#   'eval_accuracy_label_bad': 0.7523376295173111,
#   'eval_accuracy_label_good': 0.9930744496660895,
#   'eval_runtime': 16.2048,
#   'eval_samples_per_second': 493.681,
#   'eval_steps_per_second': 30.855,
#   'epoch': 1.6,
#   'step': 1600},
#  {'loss': 0.306,
#   'grad_norm': 3.691255807876587,
#   'learning_rate': 1.1120000000000002e-05,
#   'epoch': 1.6099999999999999,
#   'step': 1610},
#  {'loss': 0.2892,
#   'grad_norm': 3.506415605545044,
#   'learning_rate': 1.1040000000000001e-05,
#   'epoch': 1.62,
#   'step': 1620},
#  {'loss': 0.3178,
#   'grad_norm': 4.358609199523926,
#   'learning_rate': 1.0960000000000002e-05,
#   'epoch': 1.63,
#   'step': 1630},
#  {'loss': 0.2969,
#   'grad_norm': 4.635347843170166,
#   'learning_rate': 1.0880000000000001e-05,
#   'epoch': 1.6400000000000001,
#   'step': 1640},
#  {'loss': 0.2905,
#   'grad_norm': 32.793373107910156,
#   'learning_rate': 1.0800000000000002e-05,
#   'epoch': 1.65,
#   'step': 1650},
#  {'loss': 0.2922,
#   'grad_norm': 4.978704452514648,
#   'learning_rate': 1.072e-05,
#   'epoch': 1.6600000000000001,
#   'step': 1660},
#  {'loss': 0.2384,
#   'grad_norm': 4.120080471038818,
#   'learning_rate': 1.0640000000000001e-05,
#   'epoch': 1.67,
#   'step': 1670},
#  {'loss': 0.3405,
#   'grad_norm': 6.803117275238037,
#   'learning_rate': 1.056e-05,
#   'epoch': 1.6800000000000002,
#   'step': 1680},
#  {'loss': 0.3177,
#   'grad_norm': 7.7447428703308105,
#   'learning_rate': 1.0480000000000001e-05,
#   'epoch': 1.69,
#   'step': 1690},
#  {'loss': 0.3016,
#   'grad_norm': 4.63403844833374,
#   'learning_rate': 1.04e-05,
#   'epoch': 1.7,
#   'step': 1700},
#  {'eval_loss': 0.2952163517475128,
#   'eval_accuracy': 0.88,
#   'eval_f1': 0.8791371105958262,
#   'eval_precision': 0.8896174883640247,
#   'eval_recall': 0.88,
#   'eval_accuracy_label_bad': 0.7985847864543847,
#   'eval_accuracy_label_good': 0.9596834034133069,
#   'eval_runtime': 16.2057,
#   'eval_samples_per_second': 493.654,
#   'eval_steps_per_second': 30.853,
#   'epoch': 1.7,
#   'step': 1700},
#  {'loss': 0.2462,
#   'grad_norm': 4.3285298347473145,
#   'learning_rate': 1.0320000000000001e-05,
#   'epoch': 1.71,
#   'step': 1710},
#  {'loss': 0.3023,
#   'grad_norm': 34.260623931884766,
#   'learning_rate': 1.024e-05,
#   'epoch': 1.72,
#   'step': 1720},
#  {'loss': 0.3279,
#   'grad_norm': 3.742006778717041,
#   'learning_rate': 1.0160000000000001e-05,
#   'epoch': 1.73,
#   'step': 1730},
#  {'loss': 0.2982,
#   'grad_norm': 5.023835182189941,
#   'learning_rate': 1.008e-05,
#   'epoch': 1.74,
#   'step': 1740},
#  {'loss': 0.2669,
#   'grad_norm': 12.34023380279541,
#   'learning_rate': 1e-05,
#   'epoch': 1.75,
#   'step': 1750},
#  {'loss': 0.4157,
#   'grad_norm': 7.920289993286133,
#   'learning_rate': 9.920000000000002e-06,
#   'epoch': 1.76,
#   'step': 1760},
#  {'loss': 0.3379,
#   'grad_norm': 23.838590621948242,
#   'learning_rate': 9.84e-06,
#   'epoch': 1.77,
#   'step': 1770},
#  {'loss': 0.3341,
#   'grad_norm': 4.014834403991699,
#   'learning_rate': 9.760000000000001e-06,
#   'epoch': 1.78,
#   'step': 1780},
#  {'loss': 0.2813,
#   'grad_norm': 4.274893760681152,
#   'learning_rate': 9.68e-06,
#   'epoch': 1.79,
#   'step': 1790},
#  {'loss': 0.2818,
#   'grad_norm': 6.550471305847168,
#   'learning_rate': 9.600000000000001e-06,
#   'epoch': 1.8,
#   'step': 1800},
#  {'eval_loss': 0.31780460476875305,
#   'eval_accuracy': 0.867125,
#   'eval_f1': 0.8661436517764646,
#   'eval_precision': 0.8766626231599101,
#   'eval_recall': 0.867125,
#   'eval_accuracy_label_bad': 0.784432650998231,
#   'eval_accuracy_label_good': 0.9480583724956715,
#   'eval_runtime': 16.2355,
#   'eval_samples_per_second': 492.748,
#   'eval_steps_per_second': 30.797,
#   'epoch': 1.8,
#   'step': 1800},
#  {'loss': 0.2776,
#   'grad_norm': 12.994303703308105,
#   'learning_rate': 9.52e-06,
#   'epoch': 1.81,
#   'step': 1810},
#  {'loss': 0.2853,
#   'grad_norm': 8.332637786865234,
#   'learning_rate': 9.440000000000001e-06,
#   'epoch': 1.8199999999999998,
#   'step': 1820},
#  {'loss': 0.3138,
#   'grad_norm': 11.438555717468262,
#   'learning_rate': 9.360000000000002e-06,
#   'epoch': 1.83,
#   'step': 1830},
#  {'loss': 0.245,
#   'grad_norm': 8.813030242919922,
#   'learning_rate': 9.280000000000001e-06,
#   'epoch': 1.8399999999999999,
#   'step': 1840},
#  {'loss': 0.235,
#   'grad_norm': 20.63060188293457,
#   'learning_rate': 9.200000000000002e-06,
#   'epoch': 1.85,
#   'step': 1850},
#  {'loss': 0.2712,
#   'grad_norm': 6.959423542022705,
#   'learning_rate': 9.12e-06,
#   'epoch': 1.8599999999999999,
#   'step': 1860},
#  {'loss': 0.3061,
#   'grad_norm': 18.43301010131836,
#   'learning_rate': 9.040000000000002e-06,
#   'epoch': 1.87,
#   'step': 1870},
#  {'loss': 0.2619,
#   'grad_norm': 6.418920993804932,
#   'learning_rate': 8.96e-06,
#   'epoch': 1.88,
#   'step': 1880},
#  {'loss': 0.2377,
#   'grad_norm': 5.453137397766113,
#   'learning_rate': 8.880000000000001e-06,
#   'epoch': 1.8900000000000001,
#   'step': 1890},
#  {'loss': 0.2234,
#   'grad_norm': 18.161972045898438,
#   'learning_rate': 8.8e-06,
#   'epoch': 1.9,
#   'step': 1900},
#  {'eval_loss': 0.25104260444641113,
#   'eval_accuracy': 0.903875,
#   'eval_f1': 0.9029921089880683,
#   'eval_precision': 0.9173004371540676,
#   'eval_recall': 0.903875,
#   'eval_accuracy_label_bad': 0.8117260550922416,
#   'eval_accuracy_label_good': 0.9940638139995053,
#   'eval_runtime': 16.1921,
#   'eval_samples_per_second': 494.069,
#   'eval_steps_per_second': 30.879,
#   'epoch': 1.9,
#   'step': 1900},
#  {'loss': 0.2777,
#   'grad_norm': 6.336198329925537,
#   'learning_rate': 8.720000000000001e-06,
#   'epoch': 1.9100000000000001,
#   'step': 1910},
#  {'loss': 0.2884,
#   'grad_norm': 13.58618450164795,
#   'learning_rate': 8.64e-06,
#   'epoch': 1.92,
#   'step': 1920},
#  {'loss': 0.2426,
#   'grad_norm': 9.678337097167969,
#   'learning_rate': 8.560000000000001e-06,
#   'epoch': 1.9300000000000002,
#   'step': 1930},
#  {'loss': 0.2444,
#   'grad_norm': 14.45676326751709,
#   'learning_rate': 8.48e-06,
#   'epoch': 1.94,
#   'step': 1940},
#  {'loss': 0.2283,
#   'grad_norm': 25.383747100830078,
#   'learning_rate': 8.400000000000001e-06,
#   'epoch': 1.95,
#   'step': 1950},
#  {'loss': 0.2349,
#   'grad_norm': 9.376765251159668,
#   'learning_rate': 8.32e-06,
#   'epoch': 1.96,
#   'step': 1960},
#  {'loss': 0.2722,
#   'grad_norm': 7.674943447113037,
#   'learning_rate': 8.24e-06,
#   'epoch': 1.97,
#   'step': 1970},
#  {'loss': 0.2096,
#   'grad_norm': 14.16647720336914,
#   'learning_rate': 8.16e-06,
#   'epoch': 1.98,
#   'step': 1980},
#  {'loss': 0.2154,
#   'grad_norm': 9.12901782989502,
#   'learning_rate': 8.08e-06,
#   'epoch': 1.99,
#   'step': 1990},
#  {'loss': 0.2193,
#   'grad_norm': 25.073156356811523,
#   'learning_rate': 8.000000000000001e-06,
#   'epoch': 2.0,
#   'step': 2000},
#  {'eval_loss': 0.22523736953735352,
#   'eval_accuracy': 0.9165,
#   'eval_f1': 0.9160249184510675,
#   'eval_precision': 0.9247246421185042,
#   'eval_recall': 0.9165,
#   'eval_accuracy_label_bad': 0.8448319433914582,
#   'eval_accuracy_label_good': 0.986643581498887,
#   'eval_runtime': 16.214,
#   'eval_samples_per_second': 493.4,
#   'eval_steps_per_second': 30.837,
#   'epoch': 2.0,
#   'step': 2000},
#  {'loss': 0.2112,
#   'grad_norm': 24.333778381347656,
#   'learning_rate': 7.92e-06,
#   'epoch': 2.01,
#   'step': 2010},
#  {'loss': 0.2585,
#   'grad_norm': 28.652873992919922,
#   'learning_rate': 7.840000000000001e-06,
#   'epoch': 2.02,
#   'step': 2020},
#  {'loss': 0.2206,
#   'grad_norm': 17.4317684173584,
#   'learning_rate': 7.76e-06,
#   'epoch': 2.03,
#   'step': 2030},
#  {'loss': 0.2081,
#   'grad_norm': 33.26673889160156,
#   'learning_rate': 7.680000000000001e-06,
#   'epoch': 2.04,
#   'step': 2040},
#  {'loss': 0.2152,
#   'grad_norm': 28.12029457092285,
#   'learning_rate': 7.600000000000001e-06,
#   'epoch': 2.05,
#   'step': 2050},
#  {'loss': 0.1709,
#   'grad_norm': 21.205738067626953,
#   'learning_rate': 7.520000000000001e-06,
#   'epoch': 2.06,
#   'step': 2060},
#  {'loss': 0.1746,
#   'grad_norm': 59.1401252746582,
#   'learning_rate': 7.440000000000001e-06,
#   'epoch': 2.07,
#   'step': 2070},
#  {'loss': 0.2305,
#   'grad_norm': 18.62577247619629,
#   'learning_rate': 7.360000000000001e-06,
#   'epoch': 2.08,
#   'step': 2080},
#  {'loss': 0.2276,
#   'grad_norm': 18.44921112060547,
#   'learning_rate': 7.280000000000001e-06,
#   'epoch': 2.09,
#   'step': 2090},
#  {'loss': 0.2153,
#   'grad_norm': 13.91491985321045,
#   'learning_rate': 7.2000000000000005e-06,
#   'epoch': 2.1,
#   'step': 2100},
#  {'eval_loss': 0.24799273908138275,
#   'eval_accuracy': 0.901375,
#   'eval_f1': 0.9012670042213328,
#   'eval_precision': 0.9025907959894466,
#   'eval_recall': 0.901375,
#   'eval_accuracy_label_bad': 0.8718726307808946,
#   'eval_accuracy_label_good': 0.9302498144941875,
#   'eval_runtime': 16.203,
#   'eval_samples_per_second': 493.737,
#   'eval_steps_per_second': 30.859,
#   'epoch': 2.1,
#   'step': 2100},
#  {'loss': 0.2102,
#   'grad_norm': 13.142118453979492,
#   'learning_rate': 7.1200000000000004e-06,
#   'epoch': 2.11,
#   'step': 2110},
#  {'loss': 0.2265,
#   'grad_norm': 28.88051414489746,
#   'learning_rate': 7.04e-06,
#   'epoch': 2.12,
#   'step': 2120},
#  {'loss': 0.2762,
#   'grad_norm': 14.529457092285156,
#   'learning_rate': 6.96e-06,
#   'epoch': 2.13,
#   'step': 2130},
#  {'loss': 0.3344,
#   'grad_norm': 70.90884399414062,
#   'learning_rate': 6.88e-06,
#   'epoch': 2.14,
#   'step': 2140},
#  {'loss': 0.2631,
#   'grad_norm': 13.543909072875977,
#   'learning_rate': 6.800000000000001e-06,
#   'epoch': 2.15,
#   'step': 2150},
#  {'loss': 0.2068,
#   'grad_norm': 22.51900291442871,
#   'learning_rate': 6.720000000000001e-06,
#   'epoch': 2.16,
#   'step': 2160},
#  {'loss': 0.2636,
#   'grad_norm': 35.12375259399414,
#   'learning_rate': 6.640000000000001e-06,
#   'epoch': 2.17,
#   'step': 2170},
#  {'loss': 0.221,
#   'grad_norm': 28.13268280029297,
#   'learning_rate': 6.560000000000001e-06,
#   'epoch': 2.18,
#   'step': 2180},
#  {'loss': 0.2162,
#   'grad_norm': 55.84356689453125,
#   'learning_rate': 6.480000000000001e-06,
#   'epoch': 2.19,
#   'step': 2190},
#  {'loss': 0.2579,
#   'grad_norm': 34.8467903137207,
#   'learning_rate': 6.4000000000000006e-06,
#   'epoch': 2.2,
#   'step': 2200},
#  {'eval_loss': 0.4402206838130951,
#   'eval_accuracy': 0.80875,
#   'eval_f1': 0.807559275690851,
#   'eval_precision': 0.8180950856979105,
#   'eval_recall': 0.80875,
#   'eval_accuracy_label_bad': 0.8918372504422543,
#   'eval_accuracy_label_good': 0.7274301261439525,
#   'eval_runtime': 16.1517,
#   'eval_samples_per_second': 495.303,
#   'eval_steps_per_second': 30.956,
#   'epoch': 2.2,
#   'step': 2200},
#  {'loss': 0.2707,
#   'grad_norm': 53.435428619384766,
#   'learning_rate': 6.3200000000000005e-06,
#   'epoch': 2.21,
#   'step': 2210},
#  {'loss': 0.2342,
#   'grad_norm': 13.91357135772705,
#   'learning_rate': 6.24e-06,
#   'epoch': 2.22,
#   'step': 2220},
#  {'loss': 0.2185,
#   'grad_norm': 16.008169174194336,
#   'learning_rate': 6.16e-06,
#   'epoch': 2.23,
#   'step': 2230},
#  {'loss': 0.2543,
#   'grad_norm': 26.74382972717285,
#   'learning_rate': 6.08e-06,
#   'epoch': 2.24,
#   'step': 2240},
#  {'loss': 0.2118,
#   'grad_norm': 4.4139790534973145,
#   'learning_rate': 6e-06,
#   'epoch': 2.25,
#   'step': 2250},
#  {'loss': 0.1814,
#   'grad_norm': 28.883548736572266,
#   'learning_rate': 5.92e-06,
#   'epoch': 2.26,
#   'step': 2260},
#  {'loss': 0.1746,
#   'grad_norm': 13.906810760498047,
#   'learning_rate': 5.84e-06,
#   'epoch': 2.27,
#   'step': 2270},
#  {'loss': 0.2744,
#   'grad_norm': 22.195667266845703,
#   'learning_rate': 5.76e-06,
#   'epoch': 2.2800000000000002,
#   'step': 2280},
#  {'loss': 0.2717,
#   'grad_norm': 74.66947937011719,
#   'learning_rate': 5.68e-06,
#   'epoch': 2.29,
#   'step': 2290},
#  {'loss': 0.2487,
#   'grad_norm': 21.327783584594727,
#   'learning_rate': 5.600000000000001e-06,
#   'epoch': 2.3,
#   'step': 2300},
#  {'eval_loss': 0.20856809616088867,
#   'eval_accuracy': 0.927125,
#   'eval_f1': 0.9268007193742274,
#   'eval_precision': 0.9335796051013934,
#   'eval_recall': 0.927125,
#   'eval_accuracy_label_bad': 0.8642911296436695,
#   'eval_accuracy_label_good': 0.9886223101657186,
#   'eval_runtime': 16.1925,
#   'eval_samples_per_second': 494.055,
#   'eval_steps_per_second': 30.878,
#   'epoch': 2.3,
#   'step': 2300},
#  {'loss': 0.1978,
#   'grad_norm': 24.585176467895508,
#   'learning_rate': 5.5200000000000005e-06,
#   'epoch': 2.31,
#   'step': 2310},
#  {'loss': 0.1896,
#   'grad_norm': 12.452005386352539,
#   'learning_rate': 5.4400000000000004e-06,
#   'epoch': 2.32,
#   'step': 2320},
#  {'loss': 0.2987,
#   'grad_norm': 12.110504150390625,
#   'learning_rate': 5.36e-06,
#   'epoch': 2.33,
#   'step': 2330},
#  {'loss': 0.1971,
#   'grad_norm': 12.615549087524414,
#   'learning_rate': 5.28e-06,
#   'epoch': 2.34,
#   'step': 2340},
#  {'loss': 0.2269,
#   'grad_norm': 56.44144821166992,
#   'learning_rate': 5.2e-06,
#   'epoch': 2.35,
#   'step': 2350},
#  {'loss': 0.2023,
#   'grad_norm': 111.99828338623047,
#   'learning_rate': 5.12e-06,
#   'epoch': 2.36,
#   'step': 2360},
#  {'loss': 0.1872,
#   'grad_norm': 33.614356994628906,
#   'learning_rate': 5.04e-06,
#   'epoch': 2.37,
#   'step': 2370},
#  {'loss': 0.1753,
#   'grad_norm': 10.161301612854004,
#   'learning_rate': 4.960000000000001e-06,
#   'epoch': 2.38,
#   'step': 2380},
#  {'loss': 0.2261,
#   'grad_norm': 4.517421245574951,
#   'learning_rate': 4.880000000000001e-06,
#   'epoch': 2.39,
#   'step': 2390},
#  {'loss': 0.2212,
#   'grad_norm': 36.041873931884766,
#   'learning_rate': 4.800000000000001e-06,
#   'epoch': 2.4,
#   'step': 2400},
#  {'eval_loss': 0.19033919274806976,
#   'eval_accuracy': 0.93775,
#   'eval_f1': 0.9376587515930842,
#   'eval_precision': 0.9396526934105961,
#   'eval_recall': 0.93775,
#   'eval_accuracy_label_bad': 0.9034622188526662,
#   'eval_accuracy_label_good': 0.9713084343309424,
#   'eval_runtime': 16.2347,
#   'eval_samples_per_second': 492.772,
#   'eval_steps_per_second': 30.798,
#   'epoch': 2.4,
#   'step': 2400},
#  {'loss': 0.1835,
#   'grad_norm': 28.869089126586914,
#   'learning_rate': 4.7200000000000005e-06,
#   'epoch': 2.41,
#   'step': 2410},
#  {'loss': 0.1842,
#   'grad_norm': 15.721853256225586,
#   'learning_rate': 4.6400000000000005e-06,
#   'epoch': 2.42,
#   'step': 2420},
#  {'loss': 0.1367,
#   'grad_norm': 9.064486503601074,
#   'learning_rate': 4.56e-06,
#   'epoch': 2.43,
#   'step': 2430},
#  {'loss': 0.1819,
#   'grad_norm': 135.59881591796875,
#   'learning_rate': 4.48e-06,
#   'epoch': 2.44,
#   'step': 2440},
#  {'loss': 0.249,
#   'grad_norm': 23.211057662963867,
#   'learning_rate': 4.4e-06,
#   'epoch': 2.45,
#   'step': 2450},
#  {'loss': 0.2596,
#   'grad_norm': 20.655576705932617,
#   'learning_rate': 4.32e-06,
#   'epoch': 2.46,
#   'step': 2460},
#  {'loss': 0.2783,
#   'grad_norm': 13.529162406921387,
#   'learning_rate': 4.24e-06,
#   'epoch': 2.4699999999999998,
#   'step': 2470},
#  {'loss': 0.1594,
#   'grad_norm': 14.730683326721191,
#   'learning_rate': 4.16e-06,
#   'epoch': 2.48,
#   'step': 2480},
#  {'loss': 0.1759,
#   'grad_norm': 10.558526992797852,
#   'learning_rate': 4.08e-06,
#   'epoch': 2.49,
#   'step': 2490},
#  {'loss': 0.1697,
#   'grad_norm': 20.144243240356445,
#   'learning_rate': 4.000000000000001e-06,
#   'epoch': 2.5,
#   'step': 2500},
#  {'eval_loss': 0.17370375990867615,
#   'eval_accuracy': 0.946,
#   'eval_f1': 0.9458457385157734,
#   'eval_precision': 0.9501449224798825,
#   'eval_recall': 0.946,
#   'eval_accuracy_label_bad': 0.8966388678291635,
#   'eval_accuracy_label_good': 0.9943111550828593,
#   'eval_runtime': 16.2294,
#   'eval_samples_per_second': 492.932,
#   'eval_steps_per_second': 30.808,
#   'epoch': 2.5,
#   'step': 2500},
#  {'loss': 0.1447,
#   'grad_norm': 45.353267669677734,
#   'learning_rate': 3.920000000000001e-06,
#   'epoch': 2.51,
#   'step': 2510},
#  {'loss': 0.1847,
#   'grad_norm': 3.401789426803589,
#   'learning_rate': 3.8400000000000005e-06,
#   'epoch': 2.52,
#   'step': 2520},
#  {'loss': 0.2416,
#   'grad_norm': 12.007572174072266,
#   'learning_rate': 3.7600000000000004e-06,
#   'epoch': 2.5300000000000002,
#   'step': 2530},
#  {'loss': 0.1879,
#   'grad_norm': 26.232711791992188,
#   'learning_rate': 3.6800000000000003e-06,
#   'epoch': 2.54,
#   'step': 2540},
#  {'loss': 0.1547,
#   'grad_norm': 70.64659881591797,
#   'learning_rate': 3.6000000000000003e-06,
#   'epoch': 2.55,
#   'step': 2550},
#  {'loss': 0.1155,
#   'grad_norm': 1.7375402450561523,
#   'learning_rate': 3.52e-06,
#   'epoch': 2.56,
#   'step': 2560},
#  {'loss': 0.2127,
#   'grad_norm': 3.435920000076294,
#   'learning_rate': 3.44e-06,
#   'epoch': 2.57,
#   'step': 2570},
#  {'loss': 0.1835,
#   'grad_norm': 2.2046403884887695,
#   'learning_rate': 3.3600000000000004e-06,
#   'epoch': 2.58,
#   'step': 2580},
#  {'loss': 0.1675,
#   'grad_norm': 2.1006197929382324,
#   'learning_rate': 3.2800000000000004e-06,
#   'epoch': 2.59,
#   'step': 2590},
#  {'loss': 0.2227,
#   'grad_norm': 37.55837631225586,
#   'learning_rate': 3.2000000000000003e-06,
#   'epoch': 2.6,
#   'step': 2600},
#  {'eval_loss': 0.1869945526123047,
#   'eval_accuracy': 0.942125,
#   'eval_f1': 0.9420494355727681,
#   'eval_precision': 0.9438085041749986,
#   'eval_recall': 0.942125,
#   'eval_accuracy_label_bad': 0.9100328531715947,
#   'eval_accuracy_label_good': 0.9735345040811278,
#   'eval_runtime': 16.2074,
#   'eval_samples_per_second': 493.603,
#   'eval_steps_per_second': 30.85,
#   'epoch': 2.6,
#   'step': 2600},
#  {'loss': 0.1811,
#   'grad_norm': 29.324462890625,
#   'learning_rate': 3.12e-06,
#   'epoch': 2.61,
#   'step': 2610},
#  {'loss': 0.1681,
#   'grad_norm': 1.3398959636688232,
#   'learning_rate': 3.04e-06,
#   'epoch': 2.62,
#   'step': 2620},
#  {'loss': 0.1653,
#   'grad_norm': 68.26473236083984,
#   'learning_rate': 2.96e-06,
#   'epoch': 2.63,
#   'step': 2630},
#  {'loss': 0.1629,
#   'grad_norm': 3.4686295986175537,
#   'learning_rate': 2.88e-06,
#   'epoch': 2.64,
#   'step': 2640},
#  {'loss': 0.2387,
#   'grad_norm': 40.99003601074219,
#   'learning_rate': 2.8000000000000003e-06,
#   'epoch': 2.65,
#   'step': 2650},
#  {'loss': 0.1552,
#   'grad_norm': 10.808854103088379,
#   'learning_rate': 2.7200000000000002e-06,
#   'epoch': 2.66,
#   'step': 2660},
#  {'loss': 0.1987,
#   'grad_norm': 2.8031671047210693,
#   'learning_rate': 2.64e-06,
#   'epoch': 2.67,
#   'step': 2670},
#  {'loss': 0.1645,
#   'grad_norm': 34.34461212158203,
#   'learning_rate': 2.56e-06,
#   'epoch': 2.68,
#   'step': 2680},
#  {'loss': 0.1427,
#   'grad_norm': 23.363889694213867,
#   'learning_rate': 2.4800000000000004e-06,
#   'epoch': 2.69,
#   'step': 2690},
#  {'loss': 0.1575,
#   'grad_norm': 19.093873977661133,
#   'learning_rate': 2.4000000000000003e-06,
#   'epoch': 2.7,
#   'step': 2700},
#  {'eval_loss': 0.16352349519729614,
#   'eval_accuracy': 0.950625,
#   'eval_f1': 0.9505158915372178,
#   'eval_precision': 0.9537693387151862,
#   'eval_recall': 0.950625,
#   'eval_accuracy_label_bad': 0.9077584028304271,
#   'eval_accuracy_label_good': 0.9925797674993816,
#   'eval_runtime': 16.2241,
#   'eval_samples_per_second': 493.093,
#   'eval_steps_per_second': 30.818,
#   'epoch': 2.7,
#   'step': 2700},
#  {'loss': 0.1845,
#   'grad_norm': 40.65194320678711,
#   'learning_rate': 2.3200000000000002e-06,
#   'epoch': 2.71,
#   'step': 2710},
#  {'loss': 0.1889,
#   'grad_norm': 29.968503952026367,
#   'learning_rate': 2.24e-06,
#   'epoch': 2.7199999999999998,
#   'step': 2720},
#  {'loss': 0.1512,
#   'grad_norm': 21.787290573120117,
#   'learning_rate': 2.16e-06,
#   'epoch': 2.73,
#   'step': 2730},
#  {'loss': 0.1597,
#   'grad_norm': 14.592923164367676,
#   'learning_rate': 2.08e-06,
#   'epoch': 2.74,
#   'step': 2740},
#  {'loss': 0.1663,
#   'grad_norm': 32.71462631225586,
#   'learning_rate': 2.0000000000000003e-06,
#   'epoch': 2.75,
#   'step': 2750},
#  {'loss': 0.2194,
#   'grad_norm': 3.5622761249542236,
#   'learning_rate': 1.9200000000000003e-06,
#   'epoch': 2.76,
#   'step': 2760},
#  {'loss': 0.1676,
#   'grad_norm': 5.235458850860596,
#   'learning_rate': 1.8400000000000002e-06,
#   'epoch': 2.77,
#   'step': 2770},
#  {'loss': 0.1978,
#   'grad_norm': 17.243724822998047,
#   'learning_rate': 1.76e-06,
#   'epoch': 2.7800000000000002,
#   'step': 2780},
#  {'loss': 0.1919,
#   'grad_norm': 14.054911613464355,
#   'learning_rate': 1.6800000000000002e-06,
#   'epoch': 2.79,
#   'step': 2790},
#  {'loss': 0.16,
#   'grad_norm': 6.174320220947266,
#   'learning_rate': 1.6000000000000001e-06,
#   'epoch': 2.8,
#   'step': 2800},
#  {'eval_loss': 0.17625540494918823,
#   'eval_accuracy': 0.94625,
#   'eval_f1': 0.9461442512531331,
#   'eval_precision': 0.9489762619915351,
#   'eval_recall': 0.94625,
#   'eval_accuracy_label_bad': 0.9059893858984079,
#   'eval_accuracy_label_good': 0.9856542171654712,
#   'eval_runtime': 16.1941,
#   'eval_samples_per_second': 494.006,
#   'eval_steps_per_second': 30.875,
#   'epoch': 2.8,
#   'step': 2800},
#  {'loss': 0.125,
#   'grad_norm': 5.517047882080078,
#   'learning_rate': 1.52e-06,
#   'epoch': 2.81,
#   'step': 2810},
#  {'loss': 0.1519,
#   'grad_norm': 1.5899075269699097,
#   'learning_rate': 1.44e-06,
#   'epoch': 2.82,
#   'step': 2820},
#  {'loss': 0.1588,
#   'grad_norm': 0.8417827486991882,
#   'learning_rate': 1.3600000000000001e-06,
#   'epoch': 2.83,
#   'step': 2830},
#  {'loss': 0.168,
#   'grad_norm': 6.639502048492432,
#   'learning_rate': 1.28e-06,
#   'epoch': 2.84,
#   'step': 2840},
#  {'loss': 0.1329,
#   'grad_norm': 1.7323462963104248,
#   'learning_rate': 1.2000000000000002e-06,
#   'epoch': 2.85,
#   'step': 2850},
#  {'loss': 0.1277,
#   'grad_norm': 2.131667137145996,
#   'learning_rate': 1.12e-06,
#   'epoch': 2.86,
#   'step': 2860},
#  {'loss': 0.2261,
#   'grad_norm': 23.265939712524414,
#   'learning_rate': 1.04e-06,
#   'epoch': 2.87,
#   'step': 2870},
#  {'loss': 0.1213,
#   'grad_norm': 20.623247146606445,
#   'learning_rate': 9.600000000000001e-07,
#   'epoch': 2.88,
#   'step': 2880},
#  {'loss': 0.1564,
#   'grad_norm': 1.1968846321105957,
#   'learning_rate': 8.8e-07,
#   'epoch': 2.89,
#   'step': 2890},
#  {'loss': 0.1163,
#   'grad_norm': 12.364869117736816,
#   'learning_rate': 8.000000000000001e-07,
#   'epoch': 2.9,
#   'step': 2900},
#  {'eval_loss': 0.1563059687614441,
#   'eval_accuracy': 0.954375,
#   'eval_f1': 0.9542664515710709,
#   'eval_precision': 0.9578242916848412,
#   'eval_recall': 0.954375,
#   'eval_accuracy_label_bad': 0.9097801364670205,
#   'eval_accuracy_label_good': 0.9980212713331684,
#   'eval_runtime': 16.1607,
#   'eval_samples_per_second': 495.028,
#   'eval_steps_per_second': 30.939,
#   'epoch': 2.9,
#   'step': 2900},
#  {'loss': 0.1076,
#   'grad_norm': 35.12506103515625,
#   'learning_rate': 7.2e-07,
#   'epoch': 2.91,
#   'step': 2910},
#  {'loss': 0.1519,
#   'grad_norm': 2.257128953933716,
#   'learning_rate': 6.4e-07,
#   'epoch': 2.92,
#   'step': 2920},
#  {'loss': 0.1559,
#   'grad_norm': 60.90379333496094,
#   'learning_rate': 5.6e-07,
#   'epoch': 2.93,
#   'step': 2930},
#  {'loss': 0.2366,
#   'grad_norm': 11.476936340332031,
#   'learning_rate': 4.800000000000001e-07,
#   'epoch': 2.94,
#   'step': 2940},
#  {'loss': 0.1448,
#   'grad_norm': 10.904147148132324,
#   'learning_rate': 4.0000000000000003e-07,
#   'epoch': 2.95,
#   'step': 2950},
#  {'loss': 0.1528,
#   'grad_norm': 8.950278282165527,
#   'learning_rate': 3.2e-07,
#   'epoch': 2.96,
#   'step': 2960},
#  {'loss': 0.1526,
#   'grad_norm': 1.848828673362732,
#   'learning_rate': 2.4000000000000003e-07,
#   'epoch': 2.9699999999999998,
#   'step': 2970},
#  {'loss': 0.1385,
#   'grad_norm': 51.338348388671875,
#   'learning_rate': 1.6e-07,
#   'epoch': 2.98,
#   'step': 2980},
#  {'loss': 0.1113,
#   'grad_norm': 38.99301528930664,
#   'learning_rate': 8e-08,
#   'epoch': 2.99,
#   'step': 2990},
#  {'loss': 0.1888,
#   'grad_norm': 0.8317020535469055,
#   'learning_rate': 0.0,
#   'epoch': 3.0,
#   'step': 3000},
#  {'eval_loss': 0.1572115123271942,
#   'eval_accuracy': 0.954,
#   'eval_f1': 0.9538877078161438,
#   'eval_precision': 0.9575470183762034,
#   'eval_recall': 0.954,
#   'eval_accuracy_label_bad': 0.9087692696487237,
#   'eval_accuracy_label_good': 0.9982686124165224,
#   'eval_runtime': 16.2004,
#   'eval_samples_per_second': 493.816,
#   'eval_steps_per_second': 30.863,
#   'epoch': 3.0,
#   'step': 3000},
#  {'train_runtime': 1112.1644,
#   'train_samples_per_second': 86.318,
#   'train_steps_per_second': 2.697,
#   'total_flos': 328821450272640.0,
#   'train_loss': 0.3416156885226568,
#   'epoch': 3.0,
#   'step': 3000},
#  {'eval_loss': 0.1572115123271942,
#   'eval_accuracy': 0.954,
#   'eval_f1': 0.9538877078161438,
#   'eval_precision': 0.9575470183762034,
#   'eval_recall': 0.954,
#   'eval_accuracy_label_bad': 0.9087692696487237,
#   'eval_accuracy_label_good': 0.9982686124165224,
#   'eval_runtime': 16.1613,
#   'eval_samples_per_second': 495.008,
#   'eval_steps_per_second': 30.938,
#   'epoch': 3.0,
#   'step': 3000},
#  {'eval_loss': 0.1572115123271942,
#   'eval_accuracy': 0.954,
#   'eval_f1': 0.9538877078161438,
#   'eval_precision': 0.9575470183762034,
#   'eval_recall': 0.954,
#   'eval_accuracy_label_bad': 0.9087692696487237,
#   'eval_accuracy_label_good': 0.9982686124165224,
#   'eval_runtime': 16.3612,
#   'eval_samples_per_second': 488.962,
#   'eval_steps_per_second': 30.56,
#   'epoch': 3.0,
#   'step': 3000}]

# %%
# Extracting metrics
train_loss = [metric['train_loss'] for metric in log_history]
eval_loss = [metric['eval_loss'] for metric in log_history]
eval_accuracy = [metric['eval_accuracy'] for metric in log_history]
eval_f1 = [metric['eval_f1'] for metric in log_history]

# Steps
steps = np.arange(len(log_history))

# Plotting
plt.figure(figsize=(12, 6))

# Plot training loss
plt.subplot(2, 1, 1)
plt.plot(steps, train_loss, label='Training Loss', marker='o')
plt.plot(steps, eval_loss, label='Validation Loss', marker='x')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot evaluation metrics
plt.subplot(2, 1, 2)
plt.plot(steps, eval_accuracy, label='Validation Accuracy', marker='o')
plt.plot(steps, eval_f1, label='Validation F1 Score', marker='x')
plt.xlabel('Steps')
plt.ylabel('Score')
plt.title('Validation Metrics')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-c1f581bf2736> in <cell line: 8>()
#       6
#       7 # Extracting metrics
# ----> 8 train_loss = [metric['train_loss'] for metric in log_history]
#       9 eval_loss = [metric['eval_loss'] for metric in log_history]
#      10 eval_accuracy = [metric['eval_accuracy'] for metric in log_history]
#
# <ipython-input-75-c1f581bf2736> in <listcomp>(.0)
#       6
#       7 # Extracting metrics
# ----> 8 train_loss = [metric['train_loss'] for metric in log_history]
#       9 eval_loss = [metric['eval_loss'] for metric in log_history]
#      10 eval_accuracy = [metric['eval_accuracy'] for metric in log_history]
#
# KeyError: 'train_loss'
