# %%
log = [{'loss': 0.7211,
  'grad_norm': 11.320104598999023,
  'learning_rate': 4.0000000000000003e-07,
  'epoch': 0.01,
  'step': 10},
 {'loss': 0.709,
  'grad_norm': 4.6100969314575195,
  'learning_rate': 8.000000000000001e-07,
  'epoch': 0.02,
  'step': 20},
 {'loss': 0.6967,
  'grad_norm': 3.0533699989318848,
  'learning_rate': 1.2000000000000002e-06,
  'epoch': 0.03,
  'step': 30},
 {'loss': 0.6998,
  'grad_norm': 12.061139106750488,
  'learning_rate': 1.6000000000000001e-06,
  'epoch': 0.04,
  'step': 40},
 {'loss': 0.6981,
  'grad_norm': 12.167548179626465,
  'learning_rate': 2.0000000000000003e-06,
  'epoch': 0.05,
  'step': 50},
 {'loss': 0.6908,
  'grad_norm': 6.688600063323975,
  'learning_rate': 2.4000000000000003e-06,
  'epoch': 0.06,
  'step': 60},
 {'loss': 0.7015,
  'grad_norm': 10.708237648010254,
  'learning_rate': 2.8000000000000003e-06,
  'epoch': 0.07,
  'step': 70},
 {'loss': 0.6936,
  'grad_norm': 8.071416854858398,
  'learning_rate': 3.2000000000000003e-06,
  'epoch': 0.08,
  'step': 80},
 {'loss': 0.7007,
  'grad_norm': 16.970029830932617,
  'learning_rate': 3.6000000000000003e-06,
  'epoch': 0.09,
  'step': 90},
 {'loss': 0.6874,
  'grad_norm': 3.95888352394104,
  'learning_rate': 4.000000000000001e-06,
  'epoch': 0.1,
  'step': 100},
 {'eval_loss': 0.6826303005218506,
  'eval_accuracy': 0.5485,
  'eval_f1': 0.5153966813753215,
  'eval_precision': 0.561853158555963,
  'eval_recall': 0.5485,
  'eval_accuracy_label_bad': 0.2848101265822785,
  'eval_accuracy_label_good': 0.805679012345679,
  'eval_runtime': 15.3204,
  'eval_samples_per_second': 522.181,
  'eval_steps_per_second': 32.636,
  'epoch': 0.1,
  'step': 100},
 {'loss': 0.6986,
  'grad_norm': 5.1501851081848145,
  'learning_rate': 4.4e-06,
  'epoch': 0.11,
  'step': 110},
 {'loss': 0.6917,
  'grad_norm': 7.977489471435547,
  'learning_rate': 4.800000000000001e-06,
  'epoch': 0.12,
  'step': 120},
 {'loss': 0.6798,
  'grad_norm': 5.752070903778076,
  'learning_rate': 5.2e-06,
  'epoch': 0.13,
  'step': 130},
 {'loss': 0.6873,
  'grad_norm': 5.990800380706787,
  'learning_rate': 5.600000000000001e-06,
  'epoch': 0.14,
  'step': 140},
 {'loss': 0.674,
  'grad_norm': 4.602133750915527,
  'learning_rate': 6e-06,
  'epoch': 0.15,
  'step': 150},
 {'loss': 0.7086,
  'grad_norm': 25.932588577270508,
  'learning_rate': 6.4000000000000006e-06,
  'epoch': 0.16,
  'step': 160},
 {'loss': 0.6697,
  'grad_norm': 7.8881754875183105,
  'learning_rate': 6.800000000000001e-06,
  'epoch': 0.17,
  'step': 170},
 {'loss': 0.6515,
  'grad_norm': 26.35676383972168,
  'learning_rate': 7.2000000000000005e-06,
  'epoch': 0.18,
  'step': 180},
 {'loss': 0.6329,
  'grad_norm': 33.41218185424805,
  'learning_rate': 7.600000000000001e-06,
  'epoch': 0.19,
  'step': 190},
 {'loss': 0.6455,
  'grad_norm': 19.71155548095703,
  'learning_rate': 8.000000000000001e-06,
  'epoch': 0.2,
  'step': 200},
 {'eval_loss': 0.6213720440864563,
  'eval_accuracy': 0.6365,
  'eval_f1': 0.6125619232867645,
  'eval_precision': 0.6760185840778433,
  'eval_recall': 0.6365,
  'eval_accuracy_label_bad': 0.3868354430379747,
  'eval_accuracy_label_good': 0.88,
  'eval_runtime': 15.5692,
  'eval_samples_per_second': 513.836,
  'eval_steps_per_second': 32.115,
  'epoch': 0.2,
  'step': 200},
 {'loss': 0.6249,
  'grad_norm': 6.32328987121582,
  'learning_rate': 8.400000000000001e-06,
  'epoch': 0.21,
  'step': 210},
 {'loss': 0.6071,
  'grad_norm': 8.555244445800781,
  'learning_rate': 8.8e-06,
  'epoch': 0.22,
  'step': 220},
 {'loss': 0.586,
  'grad_norm': 16.13380241394043,
  'learning_rate': 9.200000000000002e-06,
  'epoch': 0.23,
  'step': 230},
 {'loss': 0.5765,
  'grad_norm': 4.372967720031738,
  'learning_rate': 9.600000000000001e-06,
  'epoch': 0.24,
  'step': 240},
 {'loss': 0.5175,
  'grad_norm': 8.488983154296875,
  'learning_rate': 1e-05,
  'epoch': 0.25,
  'step': 250},
 {'loss': 0.577,
  'grad_norm': 5.0356831550598145,
  'learning_rate': 1.04e-05,
  'epoch': 0.26,
  'step': 260},
 {'loss': 0.5642,
  'grad_norm': 18.5214900970459,
  'learning_rate': 1.0800000000000002e-05,
  'epoch': 0.27,
  'step': 270},
 {'loss': 0.61,
  'grad_norm': 10.902034759521484,
  'learning_rate': 1.1200000000000001e-05,
  'epoch': 0.28,
  'step': 280},
 {'loss': 0.5677,
  'grad_norm': 3.639522075653076,
  'learning_rate': 1.16e-05,
  'epoch': 0.29,
  'step': 290},
 {'loss': 0.583,
  'grad_norm': 20.569616317749023,
  'learning_rate': 1.2e-05,
  'epoch': 0.3,
  'step': 300},
 {'eval_loss': 0.5415530800819397,
  'eval_accuracy': 0.709625,
  'eval_f1': 0.692552421771443,
  'eval_precision': 0.7640402031272545,
  'eval_recall': 0.709625,
  'eval_accuracy_label_bad': 0.4739240506329114,
  'eval_accuracy_label_good': 0.9395061728395062,
  'eval_runtime': 15.91,
  'eval_samples_per_second': 502.829,
  'eval_steps_per_second': 31.427,
  'epoch': 0.3,
  'step': 300},
 {'loss': 0.5355,
  'grad_norm': 14.505483627319336,
  'learning_rate': 1.2400000000000002e-05,
  'epoch': 0.31,
  'step': 310},
 {'loss': 0.5266,
  'grad_norm': 6.3617329597473145,
  'learning_rate': 1.2800000000000001e-05,
  'epoch': 0.32,
  'step': 320},
 {'loss': 0.4847,
  'grad_norm': 48.32014465332031,
  'learning_rate': 1.3200000000000002e-05,
  'epoch': 0.33,
  'step': 330},
 {'loss': 0.5353,
  'grad_norm': 11.49704360961914,
  'learning_rate': 1.3600000000000002e-05,
  'epoch': 0.34,
  'step': 340},
 {'loss': 0.5489,
  'grad_norm': 6.836090564727783,
  'learning_rate': 1.4e-05,
  'epoch': 0.35,
  'step': 350},
 {'loss': 0.6656,
  'grad_norm': 23.46615982055664,
  'learning_rate': 1.4400000000000001e-05,
  'epoch': 0.36,
  'step': 360},
 {'loss': 0.6112,
  'grad_norm': 5.082184314727783,
  'learning_rate': 1.48e-05,
  'epoch': 0.37,
  'step': 370},
 {'loss': 0.5631,
  'grad_norm': 2.2909483909606934,
  'learning_rate': 1.5200000000000002e-05,
  'epoch': 0.38,
  'step': 380},
 {'loss': 0.6059,
  'grad_norm': 10.532949447631836,
  'learning_rate': 1.5600000000000003e-05,
  'epoch': 0.39,
  'step': 390},
 {'loss': 0.5564,
  'grad_norm': 24.30266761779785,
  'learning_rate': 1.6000000000000003e-05,
  'epoch': 0.4,
  'step': 400},
 {'eval_loss': 0.5375518202781677,
  'eval_accuracy': 0.69925,
  'eval_f1': 0.6688980495873387,
  'eval_precision': 0.8057841306589125,
  'eval_recall': 0.69925,
  'eval_accuracy_label_bad': 0.39569620253164556,
  'eval_accuracy_label_good': 0.9953086419753087,
  'eval_runtime': 16.2128,
  'eval_samples_per_second': 493.437,
  'eval_steps_per_second': 30.84,
  'epoch': 0.4,
  'step': 400},
 {'loss': 0.571,
  'grad_norm': 56.029296875,
  'learning_rate': 1.64e-05,
  'epoch': 0.41,
  'step': 410},
 {'loss': 0.5401,
  'grad_norm': 3.657550811767578,
  'learning_rate': 1.6800000000000002e-05,
  'epoch': 0.42,
  'step': 420},
 {'loss': 0.5308,
  'grad_norm': 18.211912155151367,
  'learning_rate': 1.72e-05,
  'epoch': 0.43,
  'step': 430},
 {'loss': 0.5574,
  'grad_norm': 31.122623443603516,
  'learning_rate': 1.76e-05,
  'epoch': 0.44,
  'step': 440},
 {'loss': 0.6243,
  'grad_norm': 35.99908447265625,
  'learning_rate': 1.8e-05,
  'epoch': 0.45,
  'step': 450},
 {'loss': 0.5303,
  'grad_norm': 12.035163879394531,
  'learning_rate': 1.8400000000000003e-05,
  'epoch': 0.46,
  'step': 460},
 {'loss': 0.541,
  'grad_norm': 23.665864944458008,
  'learning_rate': 1.88e-05,
  'epoch': 0.47,
  'step': 470},
 {'loss': 0.5747,
  'grad_norm': 24.720216751098633,
  'learning_rate': 1.9200000000000003e-05,
  'epoch': 0.48,
  'step': 480},
 {'loss': 0.5494,
  'grad_norm': 6.451565742492676,
  'learning_rate': 1.9600000000000002e-05,
  'epoch': 0.49,
  'step': 490},
 {'loss': 0.5791,
  'grad_norm': 20.839052200317383,
  'learning_rate': 2e-05,
  'epoch': 0.5,
  'step': 500},
 {'eval_loss': 0.49055275321006775,
  'eval_accuracy': 0.74525,
  'eval_f1': 0.7274821488163213,
  'eval_precision': 0.8251482041492093,
  'eval_recall': 0.74525,
  'eval_accuracy_label_bad': 0.490126582278481,
  'eval_accuracy_label_good': 0.9940740740740741,
  'eval_runtime': 16.4877,
  'eval_samples_per_second': 485.21,
  'eval_steps_per_second': 30.326,
  'epoch': 0.5,
  'step': 500},
 {'loss': 0.507,
  'grad_norm': 32.258846282958984,
  'learning_rate': 1.9920000000000002e-05,
  'epoch': 0.51,
  'step': 510},
 {'loss': 0.6513,
  'grad_norm': 50.448768615722656,
  'learning_rate': 1.9840000000000003e-05,
  'epoch': 0.52,
  'step': 520},
 {'loss': 0.5811,
  'grad_norm': 7.8696818351745605,
  'learning_rate': 1.976e-05,
  'epoch': 0.53,
  'step': 530},
 {'loss': 0.5637,
  'grad_norm': 5.7138285636901855,
  'learning_rate': 1.968e-05,
  'epoch': 0.54,
  'step': 540},
 {'loss': 0.601,
  'grad_norm': 52.48955535888672,
  'learning_rate': 1.9600000000000002e-05,
  'epoch': 0.55,
  'step': 550},
 {'loss': 0.5759,
  'grad_norm': 9.21457290649414,
  'learning_rate': 1.9520000000000003e-05,
  'epoch': 0.56,
  'step': 560}]

# %%
eval_steps = 100
filtered_logs = list(filter(lambda x: x['step'] % eval_steps == 0, log))

l1 = [x for x in filtered_logs if 'loss' in x]
l2  = [x for x in filtered_logs if 'loss' not in x]

c = map(lambda x,y:x|y,l1,l2)
list(c)
# Out:
# [{'loss': 0.6874,
#   'grad_norm': 3.95888352394104,
#   'learning_rate': 4.000000000000001e-06,
#   'epoch': 0.1,
#   'step': 100,
#   'eval_loss': 0.6826303005218506,
#   'eval_accuracy': 0.5485,
#   'eval_f1': 0.5153966813753215,
#   'eval_precision': 0.561853158555963,
#   'eval_recall': 0.5485,
#   'eval_accuracy_label_bad': 0.2848101265822785,
#   'eval_accuracy_label_good': 0.805679012345679,
#   'eval_runtime': 15.3204,
#   'eval_samples_per_second': 522.181,
#   'eval_steps_per_second': 32.636},
#  {'loss': 0.6455,
#   'grad_norm': 19.71155548095703,
#   'learning_rate': 8.000000000000001e-06,
#   'epoch': 0.2,
#   'step': 200,
#   'eval_loss': 0.6213720440864563,
#   'eval_accuracy': 0.6365,
#   'eval_f1': 0.6125619232867645,
#   'eval_precision': 0.6760185840778433,
#   'eval_recall': 0.6365,
#   'eval_accuracy_label_bad': 0.3868354430379747,
#   'eval_accuracy_label_good': 0.88,
#   'eval_runtime': 15.5692,
#   'eval_samples_per_second': 513.836,
# ...
